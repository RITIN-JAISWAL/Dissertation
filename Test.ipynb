# %%
def get_list_of_files(dirName):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles = allFiles + get_list_of_files(fullPath)
        else:
            allFiles.append(fullPath)
    return allFiles

# %%
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\Json")
#file_list=get_list_of_files("/Users/costin/Desktop/libjpeg-turbo")

c_files=[]
for s in file_list:
    #print(i)
    c_files.append(s)

# %%
c_files
# Out:
# ['C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\Json\\cjpegcallGraph.json',
#  'C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\Json\\djpegcallGraph.json']

# %%
def find(toBeFind, new_fd):
    with open('C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\Json\\djpegcallGraph.json') as f:
        data = json.load(f)
    
    #print(toBeFind, " : ", any(toBeFind in sublist for sublist in data[1]))
    
    #if any(toBeFind in sublist for sublist in data[1]):
    
    for call in data[1]:
        if len(call) == 2:
            if call[0] == toBeFind:
                print(toBeFind, ": True" )
                new_fd.write()

# %%
import json

with open('C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\Json\\cjpegcallGraph.json') as f:
    data = json.load(f)

with open('C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\Json\\djpegcallGraph.json') as f:
    to_be_find_data = json.load(f)
        
    
#new_fd = open("calls.json", "a+")
#new_fd.write("Now the file has more content!")
#new_fd.close()

fp = open("calls.json", 'w', encoding='utf-8')

for call in data[1]:
    #print(call)
    for i in call:
        for to_be_call in to_be_find_data[1]:
            #l = []
            if len(to_be_call) == 2:
                if to_be_call[0] == i:
                    l = []
                    l.append(to_be_call[0])
                    print(i, ": True" )
                    l.append(call[1])
                    l.append(to_be_call[1])
                    #with open("calls.json", 'w', encoding='utf-8') as fp:
                    json.dump(l, fp, ensure_ascii=False, indent=4)
                    #new_fd.write(call[1])
                    #new_fd.write(to_be_call[1])
                    del (l)

        l = []
        l.append(call)
        json.dump(l, fp, ensure_ascii=False, indent=4)
        del (l)
# Out:
# parse_switches : True
# parse_switches : True
# usage : True
# free : True
# free : True
# free : True
# parse_switches : True
# parse_switches : True
# free : True
# free : True
# free : True
# free : True
# free : True
# free : True

# %%
    
    #for call in data[1]:
    #    any('value2' in sublist for sublist in call)
        #print(call)
        #for i in call:
            #print(i)

# %%
A=[
    [
        "0=rdjpgcom.c:main",
        "1=rdjpgcom.c:keymatch"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=rdjpgcom.c:keymatch"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=rdjpgcom.c:usage"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=stdio.h:fprintf"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=externalLibrary.h:__acrt_iob_func"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=rdjpgcom.c:usage"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=externalLibrary.h:fopen"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=stdio.h:fprintf"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=externalLibrary.h:__acrt_iob_func"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=externalLibrary.h:__acrt_iob_func"
    ],
    [
        "0=rdjpgcom.c:main",
        "1=rdjpgcom.c:scan_JPEG_header"
    ],
    [
        "1=rdjpgcom.c:keymatch",
        "2=externalLibrary.h:isupper"
    ],
    [
        "1=rdjpgcom.c:keymatch",
        "2=externalLibrary.h:tolower"
    ],
    [
        "1=rdjpgcom.c:keymatch",
        "2=externalLibrary.h:isupper"
    ],
    [
        "1=rdjpgcom.c:keymatch",
        "2=externalLibrary.h:tolower"
    ],
    
]

# %%
A=[
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_decompress_struct"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_compress_struct"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_error_mgr"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_error_mgr"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jerror.c:jpeg_std_error"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jerror.c:jpeg_std_error"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpegtran.c:parse_switches"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpegtran.c:usage"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=cdjpeg.c:read_stdin"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdatasrc.c:jpeg_stdio_src"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jcopy_markers_setup"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdapimin.c:jpeg_read_header"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jtransform_request_workspace"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdtrans.c:jpeg_read_coefficients"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jctrans.c:jpeg_copy_critical_parameters"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jtransform_adjust_parameters"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=cdjpeg.c:write_stdout"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpegtran.c:parse_switches"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdatadst.c:jpeg_stdio_dest"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jctrans.c:jpeg_write_coefficients"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jcopy_markers_execute"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jcicc.c:jpeg_write_icc_profile"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jtransform_execute_transform"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jcapimin.c:jpeg_finish_compress"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jcapimin.c:jpeg_destroy_compress"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdapimin.c:jpeg_finish_decompress"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdapimin.c:jpeg_destroy_decompress"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=transupp.c:jtransform_parse_crop_spec"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jcparam.c:jpeg_simple_progression"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.h:read_scan_script"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=transupp.c:jtransform_parse_crop_spec"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jcparam.c:jpeg_simple_progression"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.h:read_scan_script"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ]
]

# %%
A=[
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:keymatch"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:keymatch"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:usage"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:usage"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:scan_JPEG_header"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:next_marker"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_SOFn"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_COM"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_COM"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ]
]

# %%
import matplotlib.pyplot as plt
import networkx as nx
half_list = A[:len(A)//2+0]
print(len(A))
print(len(half_list))
print(A[15:18])
G=nx.Graph()
G.add_edges_from(half_list)
pos = hierarchy_pos(G,"0=0=0=0=0=0=rdjpgcom.c:main")    
nx.draw(G, pos=pos, with_labels=True)
plt.savefig('hierarchy.png')
# Out:
# 33
# 16
# [['2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_2_bytes'], ['2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_1_byte'], ['2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_2_bytes']]

# %%
import networkx as nx
import random

    
def hierarchy_pos(G, root=None, width=1., vert_gap = 0.2, vert_loc = 0, xcenter = 0.5):

    '''
    From Joel's answer at https://stackoverflow.com/a/29597209/2966723.  
    Licensed under Creative Commons Attribution-Share Alike 
    
    If the graph is a tree this will return the positions to plot this in a 
    hierarchical layout.
    
    G: the graph (must be a tree)
    
    root: the root node of current branch 
    - if the tree is directed and this is not given, 
      the root will be found and used
    - if the tree is directed and this is given, then 
      the positions will be just for the descendants of this node.
    - if the tree is undirected and not given, 
      then a random choice will be used.
    
    width: horizontal space allocated for this branch - avoids overlap with other branches
    
    vert_gap: gap between levels of hierarchy
    
    vert_loc: vertical location of root
    
    xcenter: horizontal location of root
    '''
    if not nx.is_tree(G):
        raise TypeError('cannot use hierarchy_pos on a graph that is not a tree')

    if root is None:
        if isinstance(G, nx.DiGraph):
            root = next(iter(nx.topological_sort(G)))  #allows back compatibility with nx version 1.11
        else:
            root = random.choice(list(G.nodes))

    def _hierarchy_pos(G, root, width=1., vert_gap = 0.2, vert_loc = 0, xcenter = 0.5, pos = None, parent = None):
        '''
        see hierarchy_pos docstring for most arguments

        pos: a dict saying where all nodes go if they have been assigned
        parent: parent of this branch. - only affects it if non-directed

        '''
    
        if pos is None:
            pos = {root:(xcenter,vert_loc)}
        else:
            pos[root] = (xcenter, vert_loc)
        children = list(G.neighbors(root))
        if not isinstance(G, nx.DiGraph) and parent is not None:
            children.remove(parent)  
        if len(children)!=0:
            dx = width/len(children) 
            nextx = xcenter - width/2 - dx/2
            for child in children:
                nextx += dx
                pos = _hierarchy_pos(G,child, width = dx, vert_gap = vert_gap, 
                                    vert_loc = vert_loc-vert_gap, xcenter=nextx,
                                    pos=pos, parent = root)
        return pos

            
    return _hierarchy_pos(G, root, width, vert_gap, vert_loc, xcenter)

# %%
A=[
    [
        "cjpeg.c:main",
        "cjpeg.c:parse_switches"
    ],
    [
        "cjpeg.c:parse_switches",
        "cjpeg.c:usage"
    ]
]

# %%
print(type(A))
# Out:
# <class 'list'>

# %%
res = [] 
for i in A: 
    if i not in res: 
        res.append(i)

# %%
for i in res: 
    print(i[1])
# Out:
# 1=1=1=rdjpgcom.c:keymatch
# 1=1=1=rdjpgcom.c:usage
# 1=1=1=rdjpgcom.c:scan_JPEG_header
# 2=2=2=rdjpgcom.c:next_marker
# 2=2=2=rdjpgcom.c:process_SOFn
# 2=2=2=rdjpgcom.c:skip_variable
# 2=2=2=rdjpgcom.c:process_COM
# 3=3=3=rdjpgcom.c:read_1_byte
# 3=3=3=rdjpgcom.c:read_2_bytes
# 3=3=3=rdjpgcom.c:read_1_byte
# 3=3=3=rdjpgcom.c:read_2_bytes
# 3=3=3=rdjpgcom.c:read_1_byte
# 3=3=3=rdjpgcom.c:read_2_bytes
# 3=3=3=rdjpgcom.c:read_1_byte

# %%
res
# Out:
# [['0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:keymatch'],
#  ['0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:usage'],
#  ['0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:scan_JPEG_header'],
#  ['1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:next_marker'],
#  ['1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_SOFn'],
#  ['1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:skip_variable'],
#  ['1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_COM'],
#  ['2=2=2=rdjpgcom.c:next_marker', '3=3=3=rdjpgcom.c:read_1_byte'],
#  ['2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_2_bytes'],
#  ['2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_1_byte'],
#  ['2=2=2=rdjpgcom.c:skip_variable', '3=3=3=rdjpgcom.c:read_2_bytes'],
#  ['2=2=2=rdjpgcom.c:skip_variable', '3=3=3=rdjpgcom.c:read_1_byte'],
#  ['2=2=2=rdjpgcom.c:process_COM', '3=3=3=rdjpgcom.c:read_2_bytes'],
#  ['2=2=2=rdjpgcom.c:process_COM', '3=3=3=rdjpgcom.c:read_1_byte']]

# %%
from collections import Counter 
res1=[]
res2=[]
for j in A:
        res1.append(j[1])
for i in res: 
    x=(i[1])
    d = Counter(res1)
    y=(i[0])
    e = Counter(res1)
    res2.append((i[0]+" "+ "weights "+str(e[y]),(i[1]+" "+ "weights "+str(d[x]))))
    #print('{} weight{} times'.format(x, d[x]))

# %%
res2
# Out:
# [('0=0=0=0=0=0=rdjpgcom.c:main weights 0',
#   '1=1=1=rdjpgcom.c:keymatch weights 2'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main weights 0', '1=1=1=rdjpgcom.c:usage weights 2'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main weights 0',
#   '1=1=1=rdjpgcom.c:scan_JPEG_header weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header weights 1',
#   '2=2=2=rdjpgcom.c:next_marker weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header weights 1',
#   '2=2=2=rdjpgcom.c:process_SOFn weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header weights 1',
#   '2=2=2=rdjpgcom.c:skip_variable weights 3'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header weights 1',
#   '2=2=2=rdjpgcom.c:process_COM weights 2'),
#  ('2=2=2=rdjpgcom.c:next_marker weights 1',
#   '3=3=3=rdjpgcom.c:read_1_byte weights 13'),
#  ('2=2=2=rdjpgcom.c:process_SOFn weights 1',
#   '3=3=3=rdjpgcom.c:read_2_bytes weights 8'),
#  ('2=2=2=rdjpgcom.c:process_SOFn weights 1',
#   '3=3=3=rdjpgcom.c:read_1_byte weights 13'),
#  ('2=2=2=rdjpgcom.c:skip_variable weights 3',
# ...

# %%
from collections import Counter 
res1=[]
res2=[]
for j in A:
        res1.append(j[1])
for i in res: 
    x=(i[1])
    d = Counter(res1)
    y=(i[0])
    e = Counter(res1)
    res2.append((i[0],(i[1])))
    #print('{} weight{} times'.format(x, d[x]))

# %%
res3 = [] 
for i in res2: 
    if i not in res: 
        res3.append(i)

# %%
print(type(res3))
# Out:
# <class 'list'>

# %%
res3=[('0', '1', 3), ('1','2',2),('1','3',1), ('0','3', 1)]

# %%
import matplotlib.pyplot as plt
import networkx as nx
G=nx.DiGraph()
#G.add_weighted_edges_from(res3)
G.add_edges_from(A)
pos = hierarchy_pos(G,"cjpeg.c:main")    
nx.draw(G, pos=pos, with_labels=True)
plt.savefig('hierarchy.png')

# %% [markdown]
# # Final

# %%
res=[
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:keymatch"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:keymatch"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:usage"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:usage"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:scan_JPEG_header"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:next_marker"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_SOFn"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_COM"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_COM"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ]
]

# %%
res2=[]
for i in res: 
    d =res.count(i)
    res2.append((i[0],i[1]+" weights "+str(d)))

    #print('{} weight{} times'.format(x, d[x]))

# %%
res2
# Out:
# [('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:keymatch weights 1'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:usage weights 1'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main',
#   '1=1=1=rdjpgcom.c:scan_JPEG_header weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header',
#   '2=2=2=rdjpgcom.c:next_marker weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header',
#   '2=2=2=rdjpgcom.c:process_SOFn weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header',
#   '2=2=2=rdjpgcom.c:skip_variable weights 1'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header',
#   '2=2=2=rdjpgcom.c:process_COM weights 1'),
#  ('2=2=2=rdjpgcom.c:next_marker', '3=3=3=rdjpgcom.c:read_1_byte weights 1'),
#  ('2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_2_bytes weights 1'),
#  ('2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_1_byte weights 1'),
#  ('2=2=2=rdjpgcom.c:skip_variable', '3=3=3=rdjpgcom.c:read_2_bytes weights 1'),
#  ('2=2=2=rdjpgcom.c:skip_variable', '3=3=3=rdjpgcom.c:read_1_byte weights 1'),
# ...

# %%
res2
res3 = [] 
for i in res2: 
    if i not in res3: 
        res3.append(i)

# %%
print(type(res3))
# Out:
# <class 'list'>

# %%
import matplotlib.pyplot as plt
import networkx as nx
G=nx.MultiGraph()
#G.add_weighted_edges_from(res3)
G.add_edges_from(res3)
pos = hierarchy_pos(G,'0=0=0=0=0=0=rdjpgcom.c:main')    
nx.draw(G, pos=pos, with_labels=True)
plt.savefig('hierarchy.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ritin jaiswal\appdata\local\programs\python\python38\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     396     try:
# --> 397         xy = np.asarray([pos[v] for v in nodelist])
#     398     except KeyError as e:
#
# c:\users\ritin jaiswal\appdata\local\programs\python\python38\lib\site-packages\networkx\drawing\nx_pylab.py in <listcomp>(.0)
#     396     try:
# --> 397         xy = np.asarray([pos[v] for v in nodelist])
#     398     except KeyError as e:
#
# KeyError: '1=1=1=rdjpgcom.c:scan_JPEG_header'
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# ...

# %% [markdown]
# # test

# %%
res=[
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:keymatch"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:keymatch"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:usage"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:usage"
    ],
    [
        "0=0=0=0=0=0=rdjpgcom.c:main",
        "1=1=1=rdjpgcom.c:scan_JPEG_header"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:next_marker"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_SOFn"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_COM"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:process_COM"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "1=1=1=rdjpgcom.c:scan_JPEG_header",
        "2=2=2=rdjpgcom.c:skip_variable"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:next_marker",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_SOFn",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:process_COM",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_2_bytes"
    ],
    [
        "2=2=2=rdjpgcom.c:skip_variable",
        "3=3=3=rdjpgcom.c:read_1_byte"
    ]
]

# %%
res2=[]
for i in res: 
    d =res.count(i)
    res2.append((i[0],i[1]))
    #+" weights "+str(d)
    #print('{} weight{} times'.format(x, d[x]))

# %%
res2
# Out:
# [('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:keymatch'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:keymatch'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:usage'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:usage'),
#  ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:scan_JPEG_header'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:next_marker'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_SOFn'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:skip_variable'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_COM'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_COM'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:skip_variable'),
#  ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:skip_variable'),
#  ('2=2=2=rdjpgcom.c:next_marker', '3=3=3=rdjpgcom.c:read_1_byte'),
#  ('2=2=2=rdjpgcom.c:next_marker', '3=3=3=rdjpgcom.c:read_1_byte'),
# ...

# %%
res2
res3 = [] 
for i in res2: 
    if i not in res3: 
        res3.append(i)
print(res3)
# Out:
# [('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:keymatch'), ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:usage'), ('0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:scan_JPEG_header'), ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:next_marker'), ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_SOFn'), ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:skip_variable'), ('1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:process_COM'), ('2=2=2=rdjpgcom.c:next_marker', '3=3=3=rdjpgcom.c:read_1_byte'), ('2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_2_bytes'), ('2=2=2=rdjpgcom.c:process_SOFn', '3=3=3=rdjpgcom.c:read_1_byte'), ('2=2=2=rdjpgcom.c:skip_variable', '3=3=3=rdjpgcom.c:read_2_bytes'), ('2=2=2=rdjpgcom.c:skip_variable', '3=3=3=rdjpgcom.c:read_1_byte'), ('2=2=2=rdjpgcom.c:process_COM', '3=3=3=rdjpgcom.c:read_2_bytes'), ('2=2=2=rdjpgcom.c:process_COM', '3=3=3=rdjpgcom.c:read_1_byte')]

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
G=nx.DiGraph()
#G.add_weighted_edges_from(res3)
G.add_edges_from(res3)
#nx.nx_agraph.write_dot(G,'test.dot')

# same layout using matplotlib with no labels
plt.title('draw_networkx')
pos=graphviz_layout(G, prog='dot')
nx.draw(G, pos, with_labels=False, arrows=False)
plt.savefig('nx_test.png')
#pos = hierarchy_pos(G,'0=0=0=0=0=0=rdjpgcom.c:main')    
#nx.draw(G, pos=pos, with_labels=True)
#plt.savefig('hierarchy.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\users\ritin jaiswal\appdata\local\programs\python\python38\lib\site-packages\networkx\drawing\nx_agraph.py in pygraphviz_layout(G, prog, root, args)
#     282     try:
# --> 283         import pygraphviz
#     284     except ImportError:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-72ca3c677b8a> in <module>
#       9 # same layout using matplotlib with no labels
#      10 plt.title('draw_networkx')
# ---> 11 pos=graphviz_layout(G, prog='res3')
#      12 nx.draw(G, pos, with_labels=False, arrows=False)
#      13 plt.savefig('nx_test.png')
#
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

seed = 13648  # Seed random number generators for reproducibility
G = nx.DiGraph()
G.add_edges_from(res)




pos = nx.spring_layout(G)
node_sizes = [3 + 10 * i for i in range(len(G))]
M = G.number_of_edges()
edge_colors = range(2, M + 2)
edge_alphas = [(5 + i) / (M + 4) for i in range(M)]
cmap = plt.cm.plasma

nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color="indigo")
edges = nx.draw_networkx_edges(
    G,
    pos,
    node_size=node_sizes,
    arrowstyle="->",
    arrowsize=10,
    edge_color=edge_colors,
    edge_cmap=cmap,
    width=2,
)
# set alpha value for each edge
for i in range(M):
    edges[i].set_alpha(edge_alphas[i])

pc = mpl.collections.PatchCollection(edges, cmap=cmap)
pc.set_array(edge_colors)
plt.colorbar(pc)

ax = plt.gca()
ax.set_axis_off()
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.DiGraph()
G.add_edges_from(res3)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=6)
nx.draw_networkx_edges(
    G, pos, edgelist=esmall, width=6, alpha=0.5, edge_color="b", style="dashed"
)

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")

plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-300f31584949> in <module>
#       5 G.add_edges_from(res3)
#       6
# ----> 7 elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
#       8 esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]
#       9
#
# <ipython-input-146-300f31584949> in <listcomp>(.0)
#       5 G.add_edges_from(res3)
#       6
# ----> 7 elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.5]
#       8 esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]
#       9
#
# KeyError: 'weight'

# %%
import grandalf as grand
from grandalf.layouts import SugiyamaLayout


G = nx.DiGraph() # Build your networkx graph here


g = grand.utils.convert_nextworkx_graph_to_grandalf(G) # undocumented function

class defaultview(object):
    w, h = 10, 10
for v in V: v.view = defaultview()

sug = SugiyamaLayout(g.C[0])
sug.init_all() # roots=[V[0]])
sug.draw() # This is a bit of a misnomer, as grandalf doesn't actually come with any visualization methods. This method instead calculates positions

poses = {v.data: (v.view.xy[0], v.view.xy[1]) for v in g.C[0].sV} # Extracts the positions
nx.draw(G, pos=poses, with_labels=True)
import matplotlib.pyplot as plt
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-0aed6565c8ed> in <module>
#      10 class defaultview(object):
#      11     w, h = 10, 10
# ---> 12 for v in V: v.view = defaultview()
#      13
#      14 sug = SugiyamaLayout(g.C[0])
#
# NameError: name 'V' is not defined

# %%
from grandalf.graphs import Vertex,Edge,Graph,graph_core

# %%
G = nx.DiGraph()
    #output = ("main", "function")
        # Ed
G.add_edges_from(res)




pos = nx.spring_layout(G)
        # plot the nodes
nx.draw_networkx_nodes(G, pos, cmap=plt.get_cmap('jet'), 
                               node_color = 'y', node_size = 30)
nx.draw_networkx_labels(G, pos)
        # plot the edges
nx.draw_networkx_edges(G, pos, edgelist=G.edges, edge_color='b', arrows=True)
        # plt.show()
plt.savefig("call_graph.pdf")
plt.clf()

# %%
import matplotlib.pyplot as plt
import networkx as nx



G = nx.DiGraph()
    #output = ("main", "function")
        # Ed
G.add_edges_from(res)

# write in UTF-8 encoding
fh = open("edgelist.utf-8", "wb")
nx.write_multiline_adjlist(G, fh, delimiter="\t", encoding="utf-8")

# read and store in UTF-8
fh = open("edgelist.utf-8", "rb")
H = nx.read_multiline_adjlist(fh, delimiter="\t", encoding="utf-8")

for n in G.nodes():
    if n not in H:
        print(False)

print(list(G.nodes()))

pos = nx.spring_layout(G, seed=330)
nx.draw(G, pos, font_size=16, with_labels=False)
for p in pos:  # raise text positions
    pos[p][1] += 0.07
nx.draw_networkx_labels(G, pos)
ax = plt.gca()
ax.margins(0.15, 0.10)
plt.show()
# Out:
# ['0=0=0=0=0=0=rdjpgcom.c:main', '1=1=1=rdjpgcom.c:keymatch', '1=1=1=rdjpgcom.c:usage', '1=1=1=rdjpgcom.c:scan_JPEG_header', '2=2=2=rdjpgcom.c:next_marker', '2=2=2=rdjpgcom.c:process_SOFn', '2=2=2=rdjpgcom.c:skip_variable', '2=2=2=rdjpgcom.c:process_COM', '3=3=3=rdjpgcom.c:read_1_byte', '3=3=3=rdjpgcom.c:read_2_bytes']

# %%
from grandalf.graphs import Vertex,Edge,Graph,graph_core
V = [Vertex(data) for data in range(10)]
X = [(0,1),(0,2),(1,3),(2,3),(4,0),(1,4),(4,5),(5,6),(3,6),(3,7),(6,8),(7,8),(8,9),(5,9)]
E = [Edge(V[v],V[w]) for (v,w) in X]
g = Graph(V,E)
g.C

# %%
graph = nx.DiGraph()
graph.add_edges_from(res3)
pos = hierarchy_pos(graph,'0=0=0=0=0=0=rdjpgcom.c:main') 
nx.is_directed(graph) # => True
nx.is_directed_acyclic_graph(graph) # => True
plt.tight_layout()
nx.draw_networkx(graph, pos=pos, with_labels=True,arrows=True)
plt.show()
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.clf()

#print(list(G.nodes()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-53a3bdcc0f4b> in <module>
#       1 graph = nx.DiGraph()
#       2 graph.add_edges_from(res3)
# ----> 3 pos = hierarchy_pos(graph,'0=0=0=0=0=0=rdjpgcom.c:main')
#       4 nx.is_directed(graph) # => True
#       5 nx.is_directed_acyclic_graph(graph) # => True
#
# <ipython-input-8-97d2268e9eed> in hierarchy_pos(G, root, width, vert_gap, vert_loc, xcenter)
#      31     '''
#      32     if not nx.is_tree(G):
# ---> 33         raise TypeError('cannot use hierarchy_pos on a graph that is not a tree')
#      34
#      35     if root is None:
#
# TypeError: cannot use hierarchy_pos on a graph that is not a tree

# %%
from matplotlib import pyplot as plt
g1 = nx.DiGraph()
g1.add_edges_from([("root", "a"), ("a", "b"), ("a", "e"), ("b", "c"), ("b", "d"), ("d", "e")])
plt.tight_layout()
nx.draw_networkx(g1, arrows=True)
plt.show()
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.clf()
plt.show()

# %%
A=[
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_decompress_struct"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_compress_struct"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_error_mgr"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpeglib.h:jpeg_error_mgr"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jerror.c:jpeg_std_error"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jerror.c:jpeg_std_error"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpegtran.c:parse_switches"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpegtran.c:usage"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=cdjpeg.c:read_stdin"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdatasrc.c:jpeg_stdio_src"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jcopy_markers_setup"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdapimin.c:jpeg_read_header"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jtransform_request_workspace"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdtrans.c:jpeg_read_coefficients"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jctrans.c:jpeg_copy_critical_parameters"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jtransform_adjust_parameters"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=cdjpeg.c:write_stdout"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jpegtran.c:parse_switches"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdatadst.c:jpeg_stdio_dest"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jctrans.c:jpeg_write_coefficients"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jcopy_markers_execute"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jcicc.c:jpeg_write_icc_profile"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=transupp.c:jtransform_execute_transform"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jcapimin.c:jpeg_finish_compress"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jcapimin.c:jpeg_destroy_compress"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdapimin.c:jpeg_finish_decompress"
    ],
    [
        "0=0=jpegtran.c:main",
        "1=jdapimin.c:jpeg_destroy_decompress"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=transupp.c:jtransform_parse_crop_spec"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jcparam.c:jpeg_simple_progression"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.h:read_scan_script"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=transupp.c:jtransform_parse_crop_spec"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:select_transform"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.c:keymatch"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jcparam.c:jpeg_simple_progression"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=cdjpeg.h:read_scan_script"
    ],
    [
        "1=jpegtran.c:parse_switches",
        "2=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ],
    [
        "2=jpegtran.c:select_transform",
        "3=jpegtran.c:usage"
    ]
]

# %%
import clang
import clang.cindex
import os
import json
import typing
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pylab

G = nx.DiGraph()
            #output = ("main", "function")
            # Edges
G.add_edges_from(A)

pos = nx.spring_layout(G)
            # plot the nodes
nx.draw_networkx_nodes(G, pos, cmap=plt.get_cmap('jet'), 
                                   node_color = 'y', node_size = 30)
nx.draw_networkx_labels(G, pos)
            # plot the edges
nx.draw_networkx_edges(G, pos, edgelist=G.edges, edge_color='b', arrows=True)
            # plt.show()
#plt.savefig(filename+".pdf")
plt.show()

plt.clf()
leafs = [node for node in G.nodes() if G.out_degree(node)==0 ]
nodesin = [node for node in G.nodes()]
#filename = "./Temp/"+str(location)+"_leafs.json"
            #if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            #with open(filename, 'w') as fp:
                #json.dump(leafs, fp, ensure_ascii=False, indent=4)
            #filename1 = "./Temp/"+str(location)+"_nodes.json"
            #if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            #with open(filename1, 'w') as fp:
                #json.dump(nodesin, fp, ensure_ascii=False, indent=4)

# %% [markdown]
# # Final

# %%
[
    [
        "jpegtran.c:main",
        "jpegtran.c:parse_switches"
    ],
   
    [
        "jpegtran.c:parse_switches",
        "jpegtran.c:select_transform"
    ],
    
    [
        "jpegtran.c:select_transform",
        "jpegtran.c:usage"
    ]
]
