# %%
import clang
import clang.cindex
import os
import json
import typing
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import pylab

clang.cindex.Config.set_library_file('C:/Program Files/LLVM/bin/libclang.dll')
#clang.cindex.Config.set_library_file('/Users/costin/Desktop/phd_experiments/clang/llvm-install/lib/libclang.dylib')
index = clang.cindex.Index.create()

# %%
def extract_token(translation_unit, extent, punctuation_boolean, kind_boolean):
    res_tokens = []
    tokens = translation_unit.get_tokens(extent=extent)
    for token in tokens:
        if punctuation_boolean is False:
            if token.kind != clang.cindex.TokenKind.PUNCTUATION:
                if kind_boolean is False:
                    if token.kind != clang.cindex.TokenKind.COMMENT:
                        res_tokens.append(token.spelling)
                else:
                    res_tokens.append({"kind": str(token.kind), "spelling": str(token.spelling)})
        else:
            if kind_boolean is False:
                res_tokens.append(token.spelling)
            else:
                res_tokens.append({"kind": str(token.kind), "spelling": str(token.spelling)})
    return res_tokens
def writeToJSONFile(path,fileName,data):
    os.chdir(path)
    filePathNameWExt = str(path)+'\\'+str(fileName) + '.json'
    #os.remove(str(filePathNameWExt))
    with open(filePathNameWExt, 'w', encoding='utf-8') as fp:
        json.dump(data, fp, ensure_ascii=False, indent=4)

def clearing_the_global_lists():
    CALL_EXPR = []           
    STRUCT_DECL = []
    FIELD_DECL= []
    ENUM_DECL= []
    FUNCTION_DECL= []
    PARM_DECL= []
    VAR_DECL= []
    TYPEDEF_DECL= []
    ENUM_CONSTANT_DECL=[]

def get_list_of_files(dirName):
    listOfFile = os.listdir(dirName)
    allFiles = list()
    for entry in listOfFile:
        fullPath = os.path.join(dirName, entry)
        if os.path.isdir(fullPath):
            allFiles = allFiles + get_list_of_files(fullPath)
        else:
            allFiles.append(fullPath)
    return allFiles

def get_kids_edges(function_names_kids, map_fd_fc,callExpr_funcDecl):
    res=[]
    for kid_name in function_names_kids:
        #if kid_name is in map_fd_fc:
        tmp = callExpr_funcDecl.get(kid_name)
        if (kid_name!='None'):
            if tmp is not None:
                for kid in tmp:
                    if (kid_name,kid) not in res:
                        if kid is not None:
                            res.append((kid_name,kid))
                            list_kids_edges = get_kids_edges(tmp,map_fd_fc,callExpr_funcDecl)
                            for edge in list_kids_edges:
                                res.append(edge)
    return res

def print_function():
    print("CALL_EXPR",CALL_EXPR)
    print("FIELD_DECL",FIELD_DECL)
    print("ENUM_DECL",ENUM_DECL)
    print("ENUM_CONSTANT_DECL",ENUM_CONSTANT_DECL)
    print("FUNCTION_DECL",FUNCTION_DECL)
    print("PARM_DECL",PARM_DECL)
    print("VAR_DECL",VAR_DECL)
    print("TYPEDEF_DECL",TYPEDEF_DECL)

def dump_children(node):
    for c in node.get_children():
        print (c.kind, c.type.spelling)
        dump_children(c)
def func_call_another_file(function_name, list_of_filenames):
  
    for file in list_of_filenames:
        #print("function_name"+file)
        if "_funcDef" in file:
            with open(file) as input_file:
                data = json.load(input_file)
                for item in data:
#                     print (str(function_name) + " " +str(item['name']))
                    #TODO: compare string with string after removing the filename(path) from the name
                    initial_filename=(os.path.basename(file).split('_'))
                    find_list=(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+":"+function_name)
                    #print("function_name"+find_list)
                    if item["name"]==find_list:
                        #print("find_list"+find_list)
                        if(find_list=="jcstest.c:my_output_message"):
                            print("lol")
                        #return find_list
                        return item["filename"][item["filename"].rfind("\\") + 1:]
                        #print((item["filename"][item["filename"].rfind("\\") + 1:))
    return "externalLibrary.h"

# %%
CALL_EXPR = []
STRUCT_DECL = []
FIELD_DECL= []
ENUM_DECL= []
FUNCTION_DECL= []
PARM_DECL= []
VAR_DECL= []
TYPEDEF_DECL= []
ENUM_CONSTANT_DECL=[]
TOKENS = []

# Parse of childrens and extracting desired info
def traverse(node):
        for child in node.get_children():
            if str(child.location.file) == globalFileName:
#                 print(str(child.kind) + " "+ str(child.spelling))
                #if child.kind != clang.cindex.CursorKind.briefComment
                if child.kind != clang.cindex.TokenKind.COMMENT:
                    TOKENS.append(child.spelling)
                if child.kind == clang.cindex.CursorKind.VAR_DECL:
                    VAR_DECL.append(child)

                if child.kind == clang.cindex.CursorKind.CALL_EXPR:
                    CALL_EXPR.append(child)
                    #print(str(child.spelling) + " " + str(child.extent.start.line) + ":" + str(child.extent.start.column))
                    
                if child.kind == clang.cindex.CursorKind.STRUCT_DECL:
                    STRUCT_DECL.append(child)
                    
                if child.kind == clang.cindex.CursorKind.PARM_DECL:
                    PARM_DECL.append(child)
                        
                if child.kind == clang.cindex.CursorKind.FIELD_DECL:
                    FIELD_DECL.append(child)
                        
                if child.kind == clang.cindex.CursorKind.ENUM_DECL:
                    ENUM_DECL.append(child)
                        
                if child.kind == clang.cindex.CursorKind.ENUM_CONSTANT_DECL:
                    ENUM_CONSTANT_DECL.append(child)

                if child.kind == clang.cindex.CursorKind.TYPEDEF_DECL:
                    TYPEDEF_DECL.append(child)

                if child.kind == clang.cindex.CursorKind.FUNCTION_DECL:
                    FUNCTION_DECL.append(child)
                traverse(child)

# %%
import networkx as nx
import random

    
def hierarchy_pos(G, root=None, width=1., vert_gap = 0.2, vert_loc = 0, xcenter = 0.5):

    '''
    From Joel's answer at https://stackoverflow.com/a/29597209/2966723.  
    Licensed under Creative Commons Attribution-Share Alike 
    
    If the graph is a tree this will return the positions to plot this in a 
    hierarchical layout.
    
    G: the graph (must be a tree)
    
    root: the root node of current branch 
    - if the tree is directed and this is not given, 
      the root will be found and used
    - if the tree is directed and this is given, then 
      the positions will be just for the descendants of this node.
    - if the tree is undirected and not given, 
      then a random choice will be used.
    
    width: horizontal space allocated for this branch - avoids overlap with other branches
    
    vert_gap: gap between levels of hierarchy
    
    vert_loc: vertical location of root
    
    xcenter: horizontal location of root
    '''
    if not nx.is_tree(G):
        raise TypeError('cannot use hierarchy_pos on a graph that is not a tree')

    if root is None:
        if isinstance(G, nx.DiGraph):
            root = next(iter(nx.topological_sort(G)))  #allows back compatibility with nx version 1.11
        else:
            root = random.choice(list(G.nodes))

    def _hierarchy_pos(G, root, width=1., vert_gap = 0.2, vert_loc = 0, xcenter = 0.5, pos = None, parent = None):
        '''
        see hierarchy_pos docstring for most arguments

        pos: a dict saying where all nodes go if they have been assigned
        parent: parent of this branch. - only affects it if non-directed

        '''
    
        if pos is None:
            pos = {root:(xcenter,vert_loc)}
        else:
            pos[root] = (xcenter, vert_loc)
        children = list(G.neighbors(root))
        if not isinstance(G, nx.DiGraph) and parent is not None:
            children.remove(parent)  
        if len(children)!=0:
            dx = width/len(children) 
            nextx = xcenter - width/2 - dx/2
            for child in children:
                nextx += dx
                pos = _hierarchy_pos(G,child, width = dx, vert_gap = vert_gap, 
                                    vert_loc = vert_loc-vert_gap, xcenter=nextx,
                                    pos=pos, parent = root)
        return pos

            
    return _hierarchy_pos(G, root, width, vert_gap, vert_loc, xcenter)

# %%
def filter_node_list_by_node_kind(nodes: typing.Iterable[clang.cindex.Cursor],kinds: list)-> typing.Iterable[clang.cindex.Cursor]:
    result = []
    for k in nodes:
        if k.kind in kinds:
            result.append(k)
    return result
            
def filter(j):
    global CALL_EXPR
    global TOKENS
    funcDef = []
    callExprMeta = []
    callExprMetaNot=[]
    callExpr_funcDecl = {}
    ls1=[]
    index = clang.cindex.Index.create()
    translation_unit = index.parse(j, ['-x', 'c++', '-std=c++17', '-D__CODE_GENERATOR__'])
    
    all_classes = filter_node_list_by_node_kind(translation_unit.cursor.get_children(), [clang.cindex.CursorKind.FUNCTION_DECL])
    for i in all_classes:
        CALL_EXPR = []
        TOKENS.clear()
        traverse(i)
#       Generation of the FuncDef List
        if(i.location.file.name == j):    
            tmp = {'name': str(os.path.basename(i.location.file.name))+ ":"+ str(i.spelling),
                            'filename' : str(i.location.file.name),
                            'loc_start_line': str(i.extent.start.line), 
                            'loc_start_col' : str(i.extent.start.column),
                            'loc_end_line'  : str(i.extent.end.line), 
                            'loc_end_col'   : str(i.extent.end.column),
                            'function_calls': [],
                            'tokens': extract_token(translation_unit, i.extent, False, False)}
            if len(tmp["tokens"])<1:
                for token in TOKENS:
                    tmp['tokens'].append(str(token))
            funcDef.append(tmp)


#         Generation of the callExprMeta List
        #print(CALL_EXPR)
        for child in CALL_EXPR:
            if(child.location.file.name == j):
                #funcDefForChild = child.get_funcDef()
                try:
                    funcDefForChild = child.get_definition() 

                    
                    val = {"name": str(os.path.basename(funcDefForChild.location.file.name))+ ":"+ str(child.spelling),
                                "filename" : str(child.location.file.name),
                                "loc_start_line": str(child.extent.start.line),
                                "loc_start_col" : str(child.extent.start.column),
                                "loc_end_line"  : str(child.extent.end.line),
                                "loc_end_col"   : str(child.extent.end.column)}


                    callExprMeta.append(val)
                except:
                    #funcDefForChild = child.get_definition() 

                    
                    val = {"name":"externalLibrary.h:"+str(child.spelling),
                                "filename" : str(child.location.file.name),
                                "loc_start_line": str(child.extent.start.line),
                                "loc_start_col" : str(child.extent.start.column),
                                "loc_end_line"  : str(child.extent.end.line),
                                "loc_end_col"   : str(child.extent.end.column)}


                    callExprMeta.append(val)

#         Generation of the callExpr_funcDecl List                
        for func in funcDef:
            callExpr_funcDecl[func['name']] = []
            for callExpr in callExprMeta:
                if (int(callExpr['loc_start_line']) < int(func['loc_end_line']) and 
                     int(callExpr['loc_start_line']) > int(func['loc_start_line'])):
                     callExpr_funcDecl[func['name']].append(callExpr['name'])
                elif (int(callExpr['loc_end_line']) == int(func['loc_end_line']) and 
                     int(callExpr['loc_start_col']) > int(func['loc_start_line'])and int(callExpr['loc_start_col']) < int(func['loc_end_col'])):
                     callExpr_funcDecl[func['name']].append(callExpr['name'])#end_line == compare column no
                elif (int(callExpr['loc_start_line']) == int(func['loc_start_line']) and 
                     int(callExpr['loc_start_col']) > int(func['loc_start_line'])and int(callExpr['loc_start_col']) < int(func['loc_end_col'])):
                     callExpr_funcDecl[func['name']].append(callExpr['name'])#start_line == compare column no
        




    #writeToJSONFile(directory,'funcDef', funcDef)
    location1=(os.path.basename(j))
    location=location1.split(".")
    location=location[0]+location[1]
    filename = "./Temp/"+str(location)+"_funcDef.json"
    with open(filename, 'w', encoding='utf-8') as fp:
        json.dump(funcDef, fp, ensure_ascii=False, indent=4)
    filename1 = "./Temp/"+str(location)+"_callExprMeta.json"
    with open(filename1, 'w', encoding='utf-8') as fp:
        json.dump(callExprMeta, fp, ensure_ascii=False, indent=4)
    filename2 = "./Temp/"+str(location)+"_callExpr_funcDecl.json"
    with open(filename2, 'w', encoding='utf-8') as fp:
        json.dump(callExpr_funcDecl, fp, ensure_ascii=False, indent=4)

# %%
files_executed = 0

file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\libjpeg-turbo-master")
#file_list=get_list_of_files("/Users/costin/Desktop/libjpeg-turbo")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc")
directory='Temp'
if not os.path.exists(directory):
    os.makedirs(directory)
c_files=[]
for s in file_list:
    #print(i)
    if s[-2:]==".c" or s[-2:]==".h":
       c_files.append(s)
       
for j in c_files:
    #clearing_the_global_lists()
    #globalFileName=str(j)
    #print("the results for the file"+j)
    #filter(j)
    #print(j)
    try:
            clearing_the_global_lists()
            globalFileName=str(j)
            print("There are " + str(j) + " files which executed.")
            filter(j)
            files_executed=files_executed+1
    except Exception as e:
            print("There are " + str(j) + " files which failed:" )
print("Total files executed:"+str(files_executed))
# Out:
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\cderror.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\cdjpeg.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\cdjpeg.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\cjpeg.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\cmyk.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\djpeg.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jaricom.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\java\org_libjpegturbo_turbojpeg_TJ.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\java\org_libjpegturbo_turbojpeg_TJCompressor.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\java\org_libjpegturbo_turbojpeg_TJDecompressor.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\java\org_libjpegturbo_turbojpeg_TJTransformer.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcapimin.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcapistd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcarith.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jccoefct.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jccolext.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jccolor.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcdctmgr.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jchuff.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jchuff.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcicc.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcinit.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcmainct.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcmarker.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcmaster.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcomapi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcparam.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcphuff.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcprepct.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcsample.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jcstest.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jctrans.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdapimin.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdapistd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdarith.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdatadst-tj.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdatadst.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdatasrc-tj.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdatasrc.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdcoefct.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdcoefct.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdcol565.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdcolext.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdcolor.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdct.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jddctmgr.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdhuff.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdhuff.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdicc.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdinput.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmainct.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmainct.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmarker.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmaster.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmaster.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmerge.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmerge.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmrg565.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdmrgext.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdphuff.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdpostct.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdsample.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdsample.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jdtrans.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jerror.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jerror.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jfdctflt.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jfdctfst.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jfdctint.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jidctflt.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jidctfst.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jidctint.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jidctred.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jinclude.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jmemmgr.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jmemnobs.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jmemsys.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jmorecfg.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jpegcomp.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jpegint.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jpeglib.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jpegtran.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jpeg_nbits_table.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jquant1.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jquant2.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jsimd.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jsimddct.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jsimd_none.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jstdhuff.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jutils.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\jversion.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\md5\md5.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\md5\md5.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\md5\md5cmp.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\md5\md5hl.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdbmp.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdcolmap.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdgif.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdjpgcom.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdppm.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdrle.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdswitch.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\rdtarga.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\arm\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\arm64\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\i386\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\jsimd.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jccolext-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jccolor-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jcsample-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jcsample.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jdcolext-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jdcolor-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jdsample-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jfdctint-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jidctint-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jquanti-mmi.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\jsimd_mmi.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\loongson\loongson-mmintrin.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\mips\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\mips\jsimd_dspr2_asm.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\nasm\jsimdcfg.inc.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jccolor-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jcgray-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jcgryext-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jcsample-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jcsample.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jdcolor-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jdmerge-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jdsample-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jfdctfst-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jfdctint-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jidctfst-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jidctint-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jquanti-altivec.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\powerpc\jsimd_altivec.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\simd\x86_64\jsimd.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\tjbench.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\tjexample.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\tjunittest.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\tjutil.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\tjutil.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\transupp.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\transupp.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\turbojpeg-jni.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\turbojpeg.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\turbojpeg.h files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\wrbmp.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\wrgif.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\wrjpgcom.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\wrppm.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\wrrle.c files which executed.
# There are C:\Users\RITIN JAISWAL\Desktop\Msc Dissertation\libjpeg-turbo-master\libjpeg-turbo-master\wrtarga.c files which executed.
# Total files executed:155

# %%
def filter_node_list_by_node_kind(nodes: typing.Iterable[clang.cindex.Cursor],kinds: list)-> typing.Iterable[clang.cindex.Cursor]:
    result = []
    for k in nodes:
        if k.kind in kinds:
            result.append(k)
    return result
            
def filter(j):
    global CALL_EXPR
    global TOKENS
    funcDef = []
    callExprMeta = []
    callExprMetaNot=[]
    callExpr_funcDecl = {}
    ls1=[]
    index = clang.cindex.Index.create()
    translation_unit = index.parse(j, ['-x', 'c++', '-std=c++17', '-D__CODE_GENERATOR__'])
    
    all_classes = filter_node_list_by_node_kind(translation_unit.cursor.get_children(), [clang.cindex.CursorKind.FUNCTION_DECL])
    for i in all_classes:
        CALL_EXPR = []
        TOKENS.clear()
        traverse(i)
#       Generation of the FuncDef List
        if(i.location.file.name == j):    
            tmp = {'name': str(os.path.basename(i.location.file.name))+ ":"+ str(i.spelling),
                            'filename' : str(i.location.file.name),
                            'loc_start_line': str(i.extent.start.line), 
                            'loc_start_col' : str(i.extent.start.column),
                            'loc_end_line'  : str(i.extent.end.line), 
                            'loc_end_col'   : str(i.extent.end.column),
                            'function_calls': [],
                            'tokens': extract_token(translation_unit, i.extent, False, False)}
            if len(tmp["tokens"])<1:
                for token in TOKENS:
                    tmp['tokens'].append(str(token))
            funcDef.append(tmp)


#         Generation of the callExprMeta List
        #print(CALL_EXPR)
        for child in CALL_EXPR:
            if(child.location.file.name == j):
                #funcDefForChild = child.get_funcDef()
                try:
                    funcDefForChild = child.get_definition() 

                    
                    val = {"name": str(os.path.basename(funcDefForChild.location.file.name))+ ":"+ str(child.spelling),
                                "filename" : str(child.location.file.name),
                                "loc_start_line": str(child.extent.start.line),
                                "loc_start_col" : str(child.extent.start.column),
                                "loc_end_line"  : str(child.extent.end.line),
                                "loc_end_col"   : str(child.extent.end.column)}


                    callExprMeta.append(val)
                except:
                    #funcDefForChild = child.get_definition() 
                    try:
                        func_filename= func_call_another_file(child.spelling, get_list_of_files('C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Temp'))
                        val = {"name": func_filename + ":" +str(child.spelling),
                                "filename" : str(child.location.file.name),
                                "loc_start_line": str(child.extent.start.line),
                                "loc_start_col" : str(child.extent.start.column),
                                "loc_end_line"  : str(child.extent.end.line),
                                "loc_end_col"   : str(child.extent.end.column)}
                    except:
                        val = {"name":"externalLibrary.h:"+str(child.spelling),
                                "filename" : str(child.location.file.name),
                                "loc_start_line": str(child.extent.start.line),
                                "loc_start_col" : str(child.extent.start.column),
                                "loc_end_line"  : str(child.extent.end.line),
                                "loc_end_col"   : str(child.extent.end.column)}

                    callExprMeta.append(val)

#         Generation of the callExpr_funcDecl List                
        for func in funcDef:
            callExpr_funcDecl[func['name']] = []
            for callExpr in callExprMeta:
                if (int(callExpr['loc_start_line']) < int(func['loc_end_line']) and 
                     int(callExpr['loc_start_line']) > int(func['loc_start_line'])):
                     callExpr_funcDecl[func['name']].append(callExpr['name'])
                elif (int(callExpr['loc_end_line']) == int(func['loc_end_line']) and 
                     int(callExpr['loc_start_col']) > int(func['loc_start_line'])and int(callExpr['loc_start_col']) < int(func['loc_end_col'])):
                     callExpr_funcDecl[func['name']].append(callExpr['name'])#end_line == compare column no
                elif (int(callExpr['loc_start_line']) == int(func['loc_start_line']) and 
                     int(callExpr['loc_start_col']) > int(func['loc_start_line'])and int(callExpr['loc_start_col']) < int(func['loc_end_col'])):
                     callExpr_funcDecl[func['name']].append(callExpr['name'])#start_line == compare column no
        




    #writeToJSONFile(directory,'funcDef', funcDef)
    location1=(os.path.basename(j))
    location=location1.split(".")
    location=location[0]+location[1]
    filename = "./Temp/"+str(location)+"_funcDef.json"
    with open(filename, 'w', encoding='utf-8') as fp:
        json.dump(funcDef, fp, ensure_ascii=False, indent=4)
    filename1 = "./Temp/"+str(location)+"_callExprMeta.json"
    with open(filename1, 'w', encoding='utf-8') as fp:
        json.dump(callExprMeta, fp, ensure_ascii=False, indent=4)
    filename2 = "./Temp/"+str(location)+"_callExpr_funcDecl.json"
    with open(filename2, 'w', encoding='utf-8') as fp:
        json.dump(callExpr_funcDecl, fp, ensure_ascii=False, indent=4)

# %%
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\libjpeg-turbo-master")
#file_list=get_list_of_files("/Users/costin/Desktop/libjpeg-turbo")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc")
directory='Temp'
if not os.path.exists(directory):
    os.makedirs(directory)
c_files=[]
for s in file_list:
    #print(i)
    if s[-2:]==".c" or s[-2:]==".h":
       c_files.append(s)
       
for j in c_files:
    clearing_the_global_lists()
    globalFileName=str(j)
    #print("the results for the file"+j)
    filter(j)
    #print(j)

# %% [markdown]
# # Call_graph

# %%
import json
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\libjpeg-turbo-master")
#file_list=get_list_of_files("/Users/costin/Desktop/libjpeg-turbo")
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")

# function_1 check_is_from_same_file: add the kids into kid_list; remove current kid; add res_list(kid;kids_kid)
# function_2 check_is_from_another_file: add the kids into kid_list; remove current kid; add res_list(kid;kids_kid)
def check_is_from_same_file(function_call, filename,map_fd_fc):
    tmp_filename = function_call[:function_call.index(".")]
    if tmp_filename == filename:
        function_call_kids=map_fd_fc.get(function_call)
        if function_call_kids is not None:
            return function_call_kids
    return []
    
def check_is_from_another_file(function_call, list_of_filenames):
    
#     print(list_of_filenames)
    tmp_filename = function_call[:function_call.index(".")]
    for file in list_of_filenames:
        tmp_file=(os.path.basename(file).split('_'))
#         print("1 " +str(tmp_filename) + " 2 "+str(tmp_file[0]))
        if tmp_filename == str(tmp_file[0][-1:]):
#             print("got here")
            with open(file) as input_file:
                map_fd_fc = json.load(input_file)
                function_call_kids=map_fd_fc.get(function_call)
                if function_call_kids is not None:
                #print("extracted:"+str(function_call_kids))
                    return function_call_kids
    return []
#getting the files
c_files=[]
get_files=[]
for s in file_list:
    #print(i)
    if s[-14:]=="_funcDecl.json":
       c_files.append(s)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)

for j in c_files:
    initial_filename=(os.path.basename(j).split('_'))
    #getting the filename
    kid_list=[]
    with open(j) as f:
        res_edge = []
        data = json.load(f)
        
        #print(data)
    #getting the main function
        #print(j)
        kid_list=data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')
        if (kid_list!='None'):
            if kid_list is not None:
                #print(kid_list)
                for tmp_kid in kid_list:
                    kid3=tmp_kid.split(":")
                    if(kid3[0]!="externalLibrary.h" and kid3[0]!="stdio.h"):
                        res_edge.append((initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main',tmp_kid))
#                     kid_list.remove(tmp_kid)
                while len(kid_list) > 0:
    #                     print(kid_list)
                        kid = kid_list[0]
                       # print(kid)
                        
                        
                        tmp_kid_list = check_is_from_same_file(kid,initial_filename[0][:-1],data)
                        kid_list.extend(tmp_kid_list)
                        for tmp_kid in tmp_kid_list:
                            kid1=tmp_kid.split(":")
                            
                            if(kid1[0]!="externalLibrary.h" and kid1[0]!="stdio.h"):
                               # print(kid1)
                                res_edge.append((kid,tmp_kid))
                        if len(tmp_kid_list)==0:
                            
                            tmp_kid_list = check_is_from_another_file(kid,c_files)
                            kid_list.extend(tmp_kid_list)
                            for tmp_kid in tmp_kid_list:
                                kid2=tmp_kid.split(":")
                                if(kid2[0]!="externalLibrary.h" and kid2[0]!="stdio.h" ):
                                    res_edge.append((kid,tmp_kid))
                        kid_list.remove(kid_list[0])
       
        location1=(os.path.basename(j))
        location=location1.split(".")
        location=location[0]
        filename = "./Temp/"+str(location)+"_call_graph.json"
        if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            with open(filename, 'w') as fp:
                json.dump(res_edge, fp, ensure_ascii=False, indent=4)
        #print("final " + str(res_edge))

        if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            test=(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')
            print(j)
            print(test)
            G = nx.DiGraph()
            #output = ("main", "function")
            # Edges
            G.add_edges_from(res_edge)

            pos = nx.spring_layout(G)
            # plot the nodes
            nx.draw_networkx_nodes(G, pos, cmap=plt.get_cmap('jet'), 
                                   node_color = 'y', node_size = 30)
            nx.draw_networkx_labels(G, pos)
            # plot the edges
            nx.draw_networkx_edges(G, pos, edgelist=G.edges, edge_color='b', arrows=True)
            # plt.show()
            plt.savefig(filename+".pdf")
            plt.clf()
            leafs = [node for node in G.nodes() if G.out_degree(node)==0 ]
            nodesin = [node for node in G.nodes()]
            a1=[]
            #for i in nodesin:
            a1=[]
            for i in nodesin:
                for path in nx.all_simple_paths(G, source=(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main'), target=i):
                    a1.append(path)
            #nodes_reverse=nodesin.reverse()
            print(nodesin)
            print(leafs)
            print(a1)
            filename = "./Temp/"+str(location)+"_peel.json"
            #if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            with open(filename, 'w') as fp:
                json.dump(leafs, fp, ensure_ascii=False, indent=4)
            filename1 = "./Temp/"+str(location)+"_nodes.json"
            #if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            with open(filename1, 'w') as fp:
                json.dump(nodesin, fp, ensure_ascii=False, indent=4)
            filename1 = "./Temp/"+str(location)+"_paths.json"
            #if (data.get(initial_filename[0][:-1]+"."+initial_filename[0][-1:]+':main')!=None):
            with open(filename1, 'w') as fp:
                json.dump(a1, fp, ensure_ascii=False, indent=4)
# Out:
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\cjpegc_callExpr_funcDecl.json
# cjpeg.c:main
# ['cjpeg.c:main', 'jpeglib.h:jpeg_compress_struct', 'jpeglib.h:jpeg_error_mgr', 'cjpeg.c:parse_switches', 'cjpeg.c:usage', 'cjpeg.c:select_file_type']
# ['jpeglib.h:jpeg_compress_struct', 'jpeglib.h:jpeg_error_mgr', 'cjpeg.c:usage', 'cjpeg.c:select_file_type']
# [['cjpeg.c:main', 'jpeglib.h:jpeg_compress_struct'], ['cjpeg.c:main', 'jpeglib.h:jpeg_error_mgr'], ['cjpeg.c:main', 'cjpeg.c:parse_switches'], ['cjpeg.c:main', 'cjpeg.c:parse_switches', 'cjpeg.c:usage'], ['cjpeg.c:main', 'cjpeg.c:usage'], ['cjpeg.c:main', 'cjpeg.c:select_file_type']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\djpegc_callExpr_funcDecl.json
# djpeg.c:main
# ['djpeg.c:main', 'jpeglib.h:jpeg_decompress_struct', 'jpeglib.h:jpeg_error_mgr', 'djpeg.c:parse_switches', 'djpeg.c:usage']
# ['jpeglib.h:jpeg_decompress_struct', 'jpeglib.h:jpeg_error_mgr', 'djpeg.c:usage']
# [['djpeg.c:main', 'jpeglib.h:jpeg_decompress_struct'], ['djpeg.c:main', 'jpeglib.h:jpeg_error_mgr'], ['djpeg.c:main', 'djpeg.c:parse_switches'], ['djpeg.c:main', 'djpeg.c:parse_switches', 'djpeg.c:usage'], ['djpeg.c:main', 'djpeg.c:usage']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\jcstestc_callExpr_funcDecl.json
# jcstest.c:main
# ['jcstest.c:main', 'jpeglib.h:jpeg_compress_struct', 'jcstest.c:_error_mgr']
# ['jpeglib.h:jpeg_compress_struct', 'jcstest.c:_error_mgr']
# [['jcstest.c:main', 'jpeglib.h:jpeg_compress_struct'], ['jcstest.c:main', 'jcstest.c:_error_mgr']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\jpegtranc_callExpr_funcDecl.json
# jpegtran.c:main
# ['jpegtran.c:main', 'jpeglib.h:jpeg_decompress_struct', 'jpeglib.h:jpeg_compress_struct', 'jpeglib.h:jpeg_error_mgr', 'jpegtran.c:parse_switches', 'jpegtran.c:usage', 'jpegtran.c:select_transform']
# ['jpeglib.h:jpeg_decompress_struct', 'jpeglib.h:jpeg_compress_struct', 'jpeglib.h:jpeg_error_mgr', 'jpegtran.c:usage']
# [['jpegtran.c:main', 'jpeglib.h:jpeg_decompress_struct'], ['jpegtran.c:main', 'jpeglib.h:jpeg_compress_struct'], ['jpegtran.c:main', 'jpeglib.h:jpeg_error_mgr'], ['jpegtran.c:main', 'jpegtran.c:parse_switches'], ['jpegtran.c:main', 'jpegtran.c:parse_switches', 'jpegtran.c:usage'], ['jpegtran.c:main', 'jpegtran.c:parse_switches', 'jpegtran.c:select_transform', 'jpegtran.c:usage'], ['jpegtran.c:main', 'jpegtran.c:usage'], ['jpegtran.c:main', 'jpegtran.c:parse_switches', 'jpegtran.c:select_transform']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\md5cmpc_callExpr_funcDecl.json
# md5cmp.c:main
# []
# []
# []
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\rdjpgcomc_callExpr_funcDecl.json
# rdjpgcom.c:main
# ['rdjpgcom.c:main', 'rdjpgcom.c:keymatch', 'rdjpgcom.c:usage', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:next_marker', 'rdjpgcom.c:process_SOFn', 'rdjpgcom.c:skip_variable', 'rdjpgcom.c:process_COM', 'rdjpgcom.c:read_1_byte', 'rdjpgcom.c:read_2_bytes']
# ['rdjpgcom.c:keymatch', 'rdjpgcom.c:usage', 'rdjpgcom.c:read_1_byte', 'rdjpgcom.c:read_2_bytes']
# [['rdjpgcom.c:main', 'rdjpgcom.c:keymatch'], ['rdjpgcom.c:main', 'rdjpgcom.c:usage'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:next_marker'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:process_SOFn'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:skip_variable'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:process_COM'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:next_marker', 'rdjpgcom.c:read_1_byte'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:process_SOFn', 'rdjpgcom.c:read_1_byte'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:skip_variable', 'rdjpgcom.c:read_1_byte'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:process_COM', 'rdjpgcom.c:read_1_byte'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:process_SOFn', 'rdjpgcom.c:read_2_bytes'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:skip_variable', 'rdjpgcom.c:read_2_bytes'], ['rdjpgcom.c:main', 'rdjpgcom.c:scan_JPEG_header', 'rdjpgcom.c:process_COM', 'rdjpgcom.c:read_2_bytes']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\tjbenchc_callExpr_funcDecl.json
# tjbench.c:main
# ['tjbench.c:main', 'tjbench.c:usage', 'string.h:strrchr', 'string.h:strchr', 'turbojpeg.h:operator=', 'tjbench.c:decompTest', 'tjbench.c:fullTest', 'tjbench.c:formatName', 'tjbench.c:sigfig', 'tjbench.c:decomp']
# ['tjbench.c:usage', 'string.h:strrchr', 'string.h:strchr', 'turbojpeg.h:operator=', 'tjbench.c:formatName', 'tjbench.c:sigfig']
# [['tjbench.c:main', 'tjbench.c:usage'], ['tjbench.c:main', 'string.h:strrchr'], ['tjbench.c:main', 'tjbench.c:decompTest', 'string.h:strrchr'], ['tjbench.c:main', 'tjbench.c:decompTest', 'tjbench.c:decomp', 'string.h:strrchr'], ['tjbench.c:main', 'tjbench.c:fullTest', 'tjbench.c:decomp', 'string.h:strrchr'], ['tjbench.c:main', 'string.h:strchr'], ['tjbench.c:main', 'turbojpeg.h:operator='], ['tjbench.c:main', 'tjbench.c:decompTest'], ['tjbench.c:main', 'tjbench.c:fullTest'], ['tjbench.c:main', 'tjbench.c:decompTest', 'tjbench.c:formatName'], ['tjbench.c:main', 'tjbench.c:decompTest', 'tjbench.c:sigfig'], ['tjbench.c:main', 'tjbench.c:decompTest', 'tjbench.c:decomp', 'tjbench.c:sigfig'], ['tjbench.c:main', 'tjbench.c:fullTest', 'tjbench.c:sigfig'], ['tjbench.c:main', 'tjbench.c:fullTest', 'tjbench.c:decomp', 'tjbench.c:sigfig'], ['tjbench.c:main', 'tjbench.c:decompTest', 'tjbench.c:decomp'], ['tjbench.c:main', 'tjbench.c:fullTest', 'tjbench.c:decomp']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\tjexamplec_callExpr_funcDecl.json
# tjexample.c:main
# ['tjexample.c:main', 'turbojpeg.h:tjtransform', 'tjexample.c:usage', 'turbojpeg.h:operator=', 'string.h:strrchr']
# ['turbojpeg.h:tjtransform', 'tjexample.c:usage', 'turbojpeg.h:operator=', 'string.h:strrchr']
# [['tjexample.c:main', 'turbojpeg.h:tjtransform'], ['tjexample.c:main', 'tjexample.c:usage'], ['tjexample.c:main', 'turbojpeg.h:operator='], ['tjexample.c:main', 'string.h:strrchr']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\tjunittestc_callExpr_funcDecl.json
# tjunittest.c:main
# ['tjunittest.c:main', 'time.h:time', 'tjunittest.c:bmpTest', 'tjunittest.c:usage', 'tjunittest.c:overflowTest', 'tjunittest.c:doTest', 'tjunittest.c:bufSizeTest', 'tjunittest.c:doBmpTest', 'tjunittest.c:compTest', 'tjunittest.c:decompTest', 'tjunittest.c:initBitmap', 'tjunittest.c:cmpBitmap', 'tjunittest.c:initBuf', 'tjunittest.c:checkBufYUV', 'turbojpeg.h:None', 'tjunittest.c:writeJPEG', 'tjunittest.c:_decompTest', 'tjunittest.c:checkBuf']
# ['time.h:time', 'tjunittest.c:usage', 'tjunittest.c:overflowTest', 'tjunittest.c:bufSizeTest', 'tjunittest.c:initBitmap', 'tjunittest.c:cmpBitmap', 'tjunittest.c:initBuf', 'tjunittest.c:checkBufYUV', 'turbojpeg.h:None', 'tjunittest.c:writeJPEG', 'tjunittest.c:checkBuf']
# [['tjunittest.c:main', 'time.h:time'], ['tjunittest.c:main', 'tjunittest.c:bmpTest'], ['tjunittest.c:main', 'tjunittest.c:usage'], ['tjunittest.c:main', 'tjunittest.c:overflowTest'], ['tjunittest.c:main', 'tjunittest.c:doTest'], ['tjunittest.c:main', 'tjunittest.c:bufSizeTest'], ['tjunittest.c:main', 'tjunittest.c:bmpTest', 'tjunittest.c:doBmpTest'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:compTest'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:decompTest'], ['tjunittest.c:main', 'tjunittest.c:bmpTest', 'tjunittest.c:doBmpTest', 'tjunittest.c:initBitmap'], ['tjunittest.c:main', 'tjunittest.c:bmpTest', 'tjunittest.c:doBmpTest', 'tjunittest.c:cmpBitmap'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:compTest', 'tjunittest.c:initBuf'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:compTest', 'tjunittest.c:checkBufYUV'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:decompTest', 'tjunittest.c:_decompTest', 'tjunittest.c:checkBufYUV'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:compTest', 'turbojpeg.h:None'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:decompTest', 'tjunittest.c:_decompTest', 'turbojpeg.h:None'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:decompTest', 'turbojpeg.h:None'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:compTest', 'tjunittest.c:writeJPEG'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:decompTest', 'tjunittest.c:_decompTest'], ['tjunittest.c:main', 'tjunittest.c:doTest', 'tjunittest.c:decompTest', 'tjunittest.c:_decompTest', 'tjunittest.c:checkBuf']]
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\wrjpgcomc_callExpr_funcDecl.json
# wrjpgcom.c:main
# ['wrjpgcom.c:main', 'wrjpgcom.c:keymatch', 'wrjpgcom.c:usage', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:write_marker', 'wrjpgcom.c:write_2_bytes', 'wrjpgcom.c:write_1_byte', 'wrjpgcom.c:copy_rest_of_file', 'wrjpgcom.c:next_marker', 'wrjpgcom.c:copy_variable', 'wrjpgcom.c:skip_variable', 'wrjpgcom.c:read_1_byte', 'wrjpgcom.c:read_2_bytes']
# ['wrjpgcom.c:keymatch', 'wrjpgcom.c:usage', 'wrjpgcom.c:write_marker', 'wrjpgcom.c:write_2_bytes', 'wrjpgcom.c:write_1_byte', 'wrjpgcom.c:copy_rest_of_file', 'wrjpgcom.c:read_1_byte', 'wrjpgcom.c:read_2_bytes']
# [['wrjpgcom.c:main', 'wrjpgcom.c:keymatch'], ['wrjpgcom.c:main', 'wrjpgcom.c:usage'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:write_marker'], ['wrjpgcom.c:main', 'wrjpgcom.c:write_marker'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:copy_variable', 'wrjpgcom.c:write_2_bytes'], ['wrjpgcom.c:main', 'wrjpgcom.c:write_2_bytes'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:copy_variable', 'wrjpgcom.c:write_1_byte'], ['wrjpgcom.c:main', 'wrjpgcom.c:write_1_byte'], ['wrjpgcom.c:main', 'wrjpgcom.c:copy_rest_of_file'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:next_marker'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:copy_variable'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:skip_variable'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:next_marker', 'wrjpgcom.c:read_1_byte'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:copy_variable', 'wrjpgcom.c:read_1_byte'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:skip_variable', 'wrjpgcom.c:read_1_byte'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:copy_variable', 'wrjpgcom.c:read_2_bytes'], ['wrjpgcom.c:main', 'wrjpgcom.c:scan_JPEG_header', 'wrjpgcom.c:skip_variable', 'wrjpgcom.c:read_2_bytes']]

# %%
print(list(G.nodes())[0])
for node in G.nodes():
    if "main" not in node: 
        print(node)
        #print(nx.all_simple_paths(G, source=list(G.nodes())[0]),target=node)
        
generate all nodes
generate path from root to all other nodes(no root to root)
for each path:
    COnd_H( target which is  last node of path, rest of the path) = H(everything) - H(everything - target_function)
    tokens(function)
# Out:
# wrjpgcom.c:main
# wrjpgcom.c:keymatch
# wrjpgcom.c:usage
# wrjpgcom.c:scan_JPEG_header
# wrjpgcom.c:write_marker
# wrjpgcom.c:write_2_bytes
# wrjpgcom.c:write_1_byte
# wrjpgcom.c:copy_rest_of_file
# wrjpgcom.c:next_marker
# wrjpgcom.c:copy_variable
# wrjpgcom.c:skip_variable
# wrjpgcom.c:read_1_byte
# wrjpgcom.c:read_2_bytes

# %% [markdown]
# # Modified Call_graph

# %%
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")
c_files=[]
get_files=[]
for s in file_list:
    #print(i)
    if s[-15:]=="call_graph.json":
       c_files.append(s)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)
for j in c_files:
    initial_filename=(os.path.basename(j).split('_'))
    #getting the filename
    with open(j) as f:
        res_edge = []
        a = json.load(f)
     
   
        # Iterating the index 
        # same as 'for i in range(len(list))' 
        for i in a:
            #print((i))
        #     print(i[0])
        #     i[0] = i[0][i[0].find(":"):]
            if str(i[0][i[0].find(":"):]) == ":main":
                i[0] = "0=" + str(i[0])
                name=i[0] =  str(i[0])
                i[1] = "1=" + str(i[1])
            else:
        #         print(a.index(i))
                it = a.index(i)-1
                found = False
        #         print(i)
                while it >= 0 and found == False:

                    string =  str(a[it][1][a[it][1].find("=")+1:])
                    #print(string + " " + str(i[0]))
                    if string == str(i[0]):
        #                 print(a[it][1][:a[it][1].find(":")])
                        new_index = int((a[it][1][:a[it][1].find("=")])) 
                        i[0] = str(new_index)+ "=" + str(i[0])
                        i[1] = str(new_index+1) + "=" + str(i[1])
                        found = True
                    it = it-1
        #             print(it)

        #    print(i)
        #     for j in i:
        #         getting_filename2=str(j)
        #         getting_filename1=getting_filename2.split(":")
        #         print(getting_filename1[1])
        #filename = "./Temp/"+str(location)+"_call_graph.json"
        location1=(os.path.basename(j))
        location=location1.split(".")
        location=location[0]
        #print(j)
        filename = "./Temp/"+str(location)+"modified_graph.json"
        #print(filename)
        with open(filename, 'w') as fp:
            json.dump(a, fp, ensure_ascii=False, indent=4)

# %% [markdown]
# # Tokens

# %%
import json
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\libjpeg-turbo-master")
#file_list=get_list_of_files("/Users/costin/Desktop/libjpeg-turbo")
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")
def extract_all_tokens(function_call, list_of_filenames):
    #     print(list_of_filenames)
    pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    get_completefile=pathname+list_of_filenames+"_funcDef.json"
    if(os.path.isfile(get_completefile)):
        with open(get_completefile) as s:
            data1 = json.load(s)
            for search in data1:
                #print(get_completefile)
                if search["name"] ==function_call:
                    #print("function_call"+function_call)
                    #print("lol"+function_call)
                    #print("lol2"+function_call)
                    return (search["tokens"])
                    

#getting the files
c_files=[]
get_files=[]
total_tokens=0
pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
directory1 ="Entropy_Calculation"
pathdir = os.path.join(pathname, directory1)
if not os.path.isdir(pathdir):
    os.mkdir(pathdir)
        
for s in file_list:
    #print(i)
    if s[-10:]=="nodes.json":
       c_files.append(s)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)
for j in c_files:
    
    initial_filename=(os.path.basename(j).split('_'))
    leaf_pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    leaf_file=leaf_pathname+initial_filename[0]+"_"+initial_filename[1]+"_"+initial_filename[2]+"_nodes.json"
    path1 = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"
    directory = (initial_filename[0])
    path = os.path.join(path1, directory)
    if not os.path.isdir(path):
        os.mkdir(path)
    #getting the filename
#     tokens_file = []
    with open(j) as f:
        tokens_file = []
        tokens_file_all=[]
        #print(j)
        data = json.load(f)
        for nodes in data:
            #nodes=str(nodes)
            search_file=nodes.split(".")
            search_function=nodes.split(":")
            #print(search_file[0])
            #print(search_function[1])
            if (search_file[0]!="externalLibrary"):
               
                tosearch_file=search_function[0][:-2]+search_function[0][-1:]
                tokens_file=extract_all_tokens(nodes,tosearch_file)
                tokens_file_all.append(tokens_file)
                print(nodes)
        
        
        location1=(os.path.basename(j))
        location2=str(location1.split("."))
        location=location2.split("_")
        location=location[0]
        filename1 = str(path)+'\\'+str(location[2:-1])+"_full_tokens.json"
        #print("filename"+filename1)
        #print(tokens_file_all)
        with open(filename1, 'w') as fp:
            json.dump(tokens_file_all, fp, ensure_ascii=False, indent=4)
        
        with open(leaf_file) as f:
            #tokens_specific = []
            #tokens_specificfile=[]
            #print(leaf_file)
            data2 = json.load(f)
            for nodes1 in data2:
                #print("lol")
                leaf_left=[]
                #print("nodes1"+nodes1)
                tokens_specific=[]
                tokens_specificfile=[]
                for nodes in data:
                    search_file=nodes.split(".")
                    search_function=nodes.split(":")
                    #print(search_file[0])
                    if (search_file[0]!="externalLibrary" or search_file[0]!="stdio"):
                        if (nodes1!=nodes):
                            #print("nodes"+nodes)
                            #print(j)
                            #print(nodes1)
                            #print(nodes1.split(":")[1])
                            tokens_specific = []
                            #print("nodes"+nodes1)
                            #print("node"+nodes)
                            tosearch_file=search_function[0][:-2]+search_function[0][-1:]
                            tokens_specific=extract_all_tokens(nodes,tosearch_file)
                            #tokens_specificfile.append(tokens_specific)
                            tokens_specificfile.append(tokens_specific)
                            #print(tokens_specific)
                        else:
                            leaf_left=(nodes1.split(":")[1])
                            #print(j)
                            #print("leaf_left"+leaf_left)
                        #tokens_specificfile.append(tokens_specific)
                if leaf_left:
                    location1=(os.path.basename(j))
                    location2=str(location1.split("."))
                    location=location2.split("_")
                    location=location[0]
                    filename = str(path)+'\\'+str(location[2:-1])+"_"+str(leaf_left)+".json"
                    with open(filename, 'w') as fp:
                        json.dump(tokens_specificfile, fp, ensure_ascii=False, indent=4)
# Out:
# cjpeg.c:main
# jpeglib.h:jpeg_compress_struct
# jpeglib.h:jpeg_error_mgr
# cjpeg.c:parse_switches
# cjpeg.c:usage
# cjpeg.c:select_file_type
# djpeg.c:main
# jpeglib.h:jpeg_decompress_struct
# jpeglib.h:jpeg_error_mgr
# djpeg.c:parse_switches
# djpeg.c:usage
# jcstest.c:main
# jpeglib.h:jpeg_compress_struct
# jcstest.c:_error_mgr
# jpegtran.c:main
# jpeglib.h:jpeg_decompress_struct
# jpeglib.h:jpeg_compress_struct
# jpeglib.h:jpeg_error_mgr
# jpegtran.c:parse_switches
# jpegtran.c:usage
# jpegtran.c:select_transform
# rdjpgcom.c:main
# rdjpgcom.c:keymatch
# rdjpgcom.c:usage
# rdjpgcom.c:scan_JPEG_header
# rdjpgcom.c:next_marker
# rdjpgcom.c:process_SOFn
# rdjpgcom.c:skip_variable
# rdjpgcom.c:process_COM
# rdjpgcom.c:read_1_byte
# rdjpgcom.c:read_2_bytes
# tjbench.c:main
# tjbench.c:usage
# string.h:strrchr
# string.h:strchr
# turbojpeg.h:operator=
# tjbench.c:decompTest
# tjbench.c:fullTest
# tjbench.c:formatName
# tjbench.c:sigfig
# tjbench.c:decomp
# tjexample.c:main
# turbojpeg.h:tjtransform
# tjexample.c:usage
# turbojpeg.h:operator=
# string.h:strrchr
# tjunittest.c:main
# time.h:time
# tjunittest.c:bmpTest
# tjunittest.c:usage
# tjunittest.c:overflowTest
# tjunittest.c:doTest
# tjunittest.c:bufSizeTest
# tjunittest.c:doBmpTest
# tjunittest.c:compTest
# tjunittest.c:decompTest
# tjunittest.c:initBitmap
# tjunittest.c:cmpBitmap
# tjunittest.c:initBuf
# tjunittest.c:checkBufYUV
# turbojpeg.h:None
# tjunittest.c:writeJPEG
# tjunittest.c:_decompTest
# tjunittest.c:checkBuf
# wrjpgcom.c:main
# wrjpgcom.c:keymatch
# wrjpgcom.c:usage
# wrjpgcom.c:scan_JPEG_header
# wrjpgcom.c:write_marker
# wrjpgcom.c:write_2_bytes
# wrjpgcom.c:write_1_byte
# wrjpgcom.c:copy_rest_of_file
# wrjpgcom.c:next_marker
# wrjpgcom.c:copy_variable
# wrjpgcom.c:skip_variable
# wrjpgcom.c:read_1_byte
# wrjpgcom.c:read_2_bytes

# %% [markdown]
# # Test

# %%
import json
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Msc Dissertation\\libjpeg-turbo-master\\libjpeg-turbo-master")
#file_list=get_list_of_files("/Users/costin/Desktop/libjpeg-turbo")
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")
def extract_all_tokens(function_call, list_of_filenames):
    #print(list_of_filenames)
    print(function_call)
    pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    get_completefile=pathname+list_of_filenames+"_funcDef.json"
    if(os.path.isfile(get_completefile)):
        with open(get_completefile) as s:
            data1 = json.load(s)
            for search in data1:
                #print(get_completefile)
                if search["name"] ==function_call:
                    #print("function_call"+function_call)
                    #print("lol"+function_call)
                    #print("lol2"+function_call)
                    return (search["tokens"])
                    

#getting the files
c_files=[]
get_files=[]
total_tokens=0
pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
directory1 ="Entropy_Calculation"
pathdir = os.path.join(pathname, directory1)
if not os.path.isdir(pathdir):
    os.mkdir(pathdir)
        
for s in file_list:
    #print(i)
    if s[-10:]=="paths.json":
       c_files.append(s)
    #print(c_files)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)
for j in c_files:
    
    initial_filename=(os.path.basename(j).split('_'))
    #leaf_pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    #leaf_file=leaf_pathname+initial_filename[0]+"_"+initial_filename[1]+"_"+initial_filename[2]+"_nodes.json"
    path1 = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"
    directory = (initial_filename[0])
    path = os.path.join(path1, directory)
    if not os.path.isdir(path):
        os.mkdir(path)
    #getting the filename
#     tokens_file = []
    with open(j) as f:
        tokens_file = []
        tokens_file_all=[]
        #print(j)
        data = json.load(f)
#         print(data)
#         print(j)
        for node in data:
            #print(node)
            if node is not None:
                for nodes in node:
                    #print(nodes)
                    #nodes=str(nodes)
                    search_file=nodes.split(".")
                    search_function=nodes.split(":")
                    #print(search_file[0])
                    #print(search_function[1])
                    if (search_file[0]!="externalLibrary"):
                        tosearch_file=search_function[0][:-2]+search_function[0][-1:]
                        tokens_file=extract_all_tokens(nodes,tosearch_file)
                        #print(tokens_file)
                        tokens_file_all.append(tokens_file)
                        location1=(os.path.basename(j))
                        location2=str(location1.split("."))
                        location=location2.split("_")
                        location=location[0]
                        filename = str(path)+'\\'+str(location[2:-1])+"_"+str(nodes)+".json"
                #print("filename"+filename1)
                #print(tokens_file_all)
                        with open(filename, 'w') as fp:
                            json.dump(tokens_file_all, fp, ensure_ascii=False, indent=4)
                   #print(tokens_file)
# Out:
# cjpegc
# cjpeg.c:main
# jpeglibh
# jpeglib.h:jpeg_compress_struct
# cjpegc
# cjpeg.c:main
# jpeglibh
# jpeglib.h:jpeg_error_mgr
# cjpegc
# cjpeg.c:main
# cjpegc
# cjpeg.c:parse_switches
# cjpegc
# cjpeg.c:main
# cjpegc
# cjpeg.c:parse_switches
# cjpegc
# cjpeg.c:usage
# cjpegc
# cjpeg.c:main
# cjpegc
# cjpeg.c:usage
# cjpegc
# cjpeg.c:main
# cjpegc
# cjpeg.c:select_file_type
# djpegc
# djpeg.c:main
# jpeglibh
# jpeglib.h:jpeg_decompress_struct
# djpegc
# djpeg.c:main
# jpeglibh
# jpeglib.h:jpeg_error_mgr
# djpegc
# djpeg.c:main
# djpegc
# djpeg.c:parse_switches
# djpegc
# djpeg.c:main
# djpegc
# djpeg.c:parse_switches
# djpegc
# djpeg.c:usage
# djpegc
# djpeg.c:main
# djpegc
# djpeg.c:usage
# jcstestc
# jcstest.c:main
# jpeglibh
# jpeglib.h:jpeg_compress_struct
# jcstestc
# jcstest.c:main
# jcstestc
# jcstest.c:_error_mgr
# jpegtranc
# jpegtran.c:main
# jpeglibh
# jpeglib.h:jpeg_decompress_struct
# jpegtranc
# jpegtran.c:main
# jpeglibh
# jpeglib.h:jpeg_compress_struct
# jpegtranc
# jpegtran.c:main
# jpeglibh
# jpeglib.h:jpeg_error_mgr
# jpegtranc
# jpegtran.c:main
# jpegtranc
# jpegtran.c:parse_switches
# jpegtranc
# jpegtran.c:main
# jpegtranc
# jpegtran.c:parse_switches
# jpegtranc
# jpegtran.c:usage
# jpegtranc
# jpegtran.c:main
# jpegtranc
# jpegtran.c:parse_switches
# jpegtranc
# jpegtran.c:select_transform
# jpegtranc
# jpegtran.c:usage
# jpegtranc
# jpegtran.c:main
# jpegtranc
# jpegtran.c:usage
# jpegtranc
# jpegtran.c:main
# jpegtranc
# jpegtran.c:parse_switches
# jpegtranc
# jpegtran.c:select_transform
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:keymatch
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:usage
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:next_marker
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:process_SOFn
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:skip_variable
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:process_COM
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:next_marker
# rdjpgcomc
# rdjpgcom.c:read_1_byte
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:process_SOFn
# rdjpgcomc
# rdjpgcom.c:read_1_byte
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:skip_variable
# rdjpgcomc
# rdjpgcom.c:read_1_byte
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:process_COM
# rdjpgcomc
# rdjpgcom.c:read_1_byte
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:process_SOFn
# rdjpgcomc
# rdjpgcom.c:read_2_bytes
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:skip_variable
# rdjpgcomc
# rdjpgcom.c:read_2_bytes
# rdjpgcomc
# rdjpgcom.c:main
# rdjpgcomc
# rdjpgcom.c:scan_JPEG_header
# rdjpgcomc
# rdjpgcom.c:process_COM
# rdjpgcomc
# rdjpgcom.c:read_2_bytes
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:usage
# tjbenchc
# tjbench.c:main
# stringh
# string.h:strrchr
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# stringh
# string.h:strrchr
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# tjbenchc
# tjbench.c:decomp
# stringh
# string.h:strrchr
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:fullTest
# tjbenchc
# tjbench.c:decomp
# stringh
# string.h:strrchr
# tjbenchc
# tjbench.c:main
# stringh
# string.h:strchr
# tjbenchc
# tjbench.c:main
# turbojpegh
# turbojpeg.h:operator=
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:fullTest
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# tjbenchc
# tjbench.c:formatName
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# tjbenchc
# tjbench.c:sigfig
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# tjbenchc
# tjbench.c:decomp
# tjbenchc
# tjbench.c:sigfig
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:fullTest
# tjbenchc
# tjbench.c:sigfig
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:fullTest
# tjbenchc
# tjbench.c:decomp
# tjbenchc
# tjbench.c:sigfig
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:decompTest
# tjbenchc
# tjbench.c:decomp
# tjbenchc
# tjbench.c:main
# tjbenchc
# tjbench.c:fullTest
# tjbenchc
# tjbench.c:decomp
# tjexamplec
# tjexample.c:main
# turbojpegh
# turbojpeg.h:tjtransform
# tjexamplec
# tjexample.c:main
# tjexamplec
# tjexample.c:usage
# tjexamplec
# tjexample.c:main
# turbojpegh
# turbojpeg.h:operator=
# tjexamplec
# tjexample.c:main
# stringh
# string.h:strrchr
# tjunittestc
# tjunittest.c:main
# timeh
# time.h:time
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:bmpTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:usage
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:overflowTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:bufSizeTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:bmpTest
# tjunittestc
# tjunittest.c:doBmpTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:compTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:decompTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:bmpTest
# tjunittestc
# tjunittest.c:doBmpTest
# tjunittestc
# tjunittest.c:initBitmap
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:bmpTest
# tjunittestc
# tjunittest.c:doBmpTest
# tjunittestc
# tjunittest.c:cmpBitmap
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:compTest
# tjunittestc
# tjunittest.c:initBuf
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:compTest
# tjunittestc
# tjunittest.c:checkBufYUV
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:decompTest
# tjunittestc
# tjunittest.c:_decompTest
# tjunittestc
# tjunittest.c:checkBufYUV
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:compTest
# turbojpegh
# turbojpeg.h:None
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:decompTest
# tjunittestc
# tjunittest.c:_decompTest
# turbojpegh
# turbojpeg.h:None
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:decompTest
# turbojpegh
# turbojpeg.h:None
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:compTest
# tjunittestc
# tjunittest.c:writeJPEG
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:decompTest
# tjunittestc
# tjunittest.c:_decompTest
# tjunittestc
# tjunittest.c:main
# tjunittestc
# tjunittest.c:doTest
# tjunittestc
# tjunittest.c:decompTest
# tjunittestc
# tjunittest.c:_decompTest
# tjunittestc
# tjunittest.c:checkBuf
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:keymatch
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:usage
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:write_marker
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:write_marker
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:copy_variable
# wrjpgcomc
# wrjpgcom.c:write_2_bytes
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:write_2_bytes
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:copy_variable
# wrjpgcomc
# wrjpgcom.c:write_1_byte
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:write_1_byte
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:copy_rest_of_file
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:next_marker
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:copy_variable
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:skip_variable
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:next_marker
# wrjpgcomc
# wrjpgcom.c:read_1_byte
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:copy_variable
# wrjpgcomc
# wrjpgcom.c:read_1_byte
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:skip_variable
# wrjpgcomc
# wrjpgcom.c:read_1_byte
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:copy_variable
# wrjpgcomc
# wrjpgcom.c:read_2_bytes
# wrjpgcomc
# wrjpgcom.c:main
# wrjpgcomc
# wrjpgcom.c:scan_JPEG_header
# wrjpgcomc
# wrjpgcom.c:skip_variable
# wrjpgcomc
# wrjpgcom.c:read_2_bytes

# %% [markdown]
# # Entropy

# %%
import dit
import re
import hashlib
from collections import Counter
from decimal import *


def utf_encode(string):
    if isinstance(string, str):
        string = string.encode('utf-8')
    return str(string)


def is_list_empty(input_list):
    if isinstance(input_list, list):  # Is a list
        return all(map(is_list_empty, input_list))
    return False


# Splits elements of list for uppercase
def prepare_to_process(input_list, further_tokenizing):
    final_list = []
    input_list = [item for item in input_list if item]
    if (any(isinstance(i, list) for i in input_list)) is True:
        input_list = [a for b in input_list for a in b]
    input_list = [item for item in input_list if item != 'None']
    input_list = [item for item in input_list if item != '']

    if further_tokenizing is True:
        for item in input_list:
            words_list = re.findall('([A-Z](?=[a-z]+[0-9]*)[a-z]*[0-9]*|[A-Z]+(?=[A-Z]{2,})[A-Z])', item)
            if len(words_list) > 0:
                for word in words_list:
                    final_list.append(word)
            else:
                final_list.append(item)
    else:
        final_list = input_list
        return final_list

    final_list = [e for e in final_list if e]
    #count=len(final_list)
    #print(count)
    return final_list


# probabilities for a list
def pmf(input_list, size_of_hash):
    v = []
    for item in input_list:
        h = hashlib.blake2b(digest_size=size_of_hash)
        h.update(item.encode('utf-8'))
        v.append(h.hexdigest())

    C = Counter(v)
    total = float(sum(C.values()))
    for key in C:
        C[key] = Decimal(C[key] / total)
    return [k for k, v in C.items()], [v for k, v in C.items()]


# Entropy calculation for a list; returns value or None if list is empty
def calculate_entropy(input_list, further_tokenizing):
    done = False
    size_of_hash = 60

    if is_list_empty(input_list) is True:
        return None

    while not done:
        try:
            # Process the list, Calculate the probabilities, distribution and entropy
            input_list = prepare_to_process(input_list, further_tokenizing)
            count=(len(input_list)) #<- here should be final form of the list
            p_list = pmf(input_list, size_of_hash)
            d_list = dit.Distribution(p_list[0], p_list[1])
            entropy_list = dit.shannon.entropy(d_list)
            done = True
        except Exception as e:
            if str(e) != "Python int too large to convert to C long":
                # traceback.print_exc(file=sys.stdout)
                if str(e) == "`outcomes` must be nonempty if no sample space is given":
                    print("ERROR: " + str(e) + '\n\n')
                else:
                    print("ERROR: " + str(e) + '\n\n')
            # hashing on different sizes cuz of error.
            elif str(e) == "Python int too large to convert to C long":
                if size_of_hash is 60:
                    size_of_hash = 40
                    continue
                if size_of_hash is 40:
                    size_of_hash = 20
                    continue
                if size_of_hash is 20:
                    size_of_hash = 15
                    continue
                if size_of_hash is 15:
                    size_of_hash = 10
                    continue
                done = True
            None
    return entropy_list
# Out:
# <>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:94: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:94: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-303a49488abc>:88: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if size_of_hash is 60:
# <ipython-input-12-303a49488abc>:91: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if size_of_hash is 40:
# <ipython-input-12-303a49488abc>:94: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if size_of_hash is 20:
# <ipython-input-12-303a49488abc>:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if size_of_hash is 15:

# %%
folder_paths = []
import json
MYDIR="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation"
for entry_name in os.listdir(MYDIR):
    entry_path = os.path.join(MYDIR,entry_name)
    if os.path.isdir(entry_path):
        folder_paths.append(entry_path)
for item in folder_paths:
    entropy_list=[]
    for entry_name in os.listdir(item):
        #print(entry_name)
        file=item+"\\"+entry_name
        entry_name1=(os.path.basename(entry_name).split('.'))
        with open(file) as f:
            token_list = json.load(f)

            entropy_value = calculate_entropy(token_list, False)
            entropy_list.append((entry_name1[0],entropy_value))
    filename = item+"entropy_calculations.json"
    with open(filename, 'w') as fp:
        json.dump(entropy_list, fp, ensure_ascii=False, indent=4)

# %%
count

# %%
entropy_list

# %%
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Temp\\Entropy_Calculation")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")
c_files=[]
get_files=[]
for s in file_list:
    #print(i)
    if s[-10:]=="tions.json":
       c_files.append(s)
    #print(c_files)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)
for j in c_files:
    initial_filename=(os.path.basename(j).split('_'))
    with open(j) as f:
        data = json.load(f)
        for int1 in data:
        #print(int1[0])
            b=int1[0]
            plt.scatter(b,int1[1], data=int1[1],label=int1[0])
        plt.xlabel("Functions")
        plt.ylabel("Entropy")
        plt.legend(loc="best")
        #plt.show()
        plt.savefig(initial_filename[0]+'.png')
        plt.clf()
        plt.show()  
        plt.close()

# %%
def extract_all_tokens(function_call, list_of_filenames):
    print(function_call)
    pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    get_completefile=pathname+list_of_filenames+"_funcDef.json"
    if(os.path.isfile(get_completefile)):
        with open(get_completefile) as s:
            data1 = json.load(s)
            for search in data1:
                #print(get_completefile)
                if search["name"] ==function_call:
                    #print("function_call"+function_call)
                    #print("lol"+function_call)
                    #print("lol2"+function_call)
                    return (search["tokens"])

# %%
c_files=[]
for s in file_list:
    #print(i)
    if s[-35:]=="cjpegc_callExpr_funcDecl_paths.json":
       c_files.append(s)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)

for file in c_files:
    with open(file) as path_list_file:
        path_list = json.load(path_list_file)
        for path in path_list[4:5]:
            print(path)
            for node in reversed(path[1:]):
#                 print(node)
# #                 print(path[:path.index(node)])
                
                joint_list = path[:path.index(node)+1]
                knowing_list = path[:path.index(node)]
            
                print(joint_list)
                tokens_joint=[]
                for iterator in joint_list:
                    print(iterator)
                    tokens_joint = extract_all_tokens(iterator.split(":")[1],iterator.split(":")[0])
                    calculate_entropy()
                    print(tokens_joint)
#                     print(iterator.split(":")[0])
#                 print("joint" + str(joint_list))
# Out:
# ['cjpeg.c:main', 'cjpeg.c:usage']
# ['cjpeg.c:main', 'cjpeg.c:usage']
# cjpeg.c:main
# main
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-df3ebc9dec8e> in <module>
#      25                     print(iterator)
#      26                     tokens_joint = extract_all_tokens(iterator.split(":")[1],iterator.split(":")[0])
# ---> 27                     calculate_entropy()
#      28                     print(tokens_joint)
#      29 #                     print(iterator.split(":")[0])
#
# NameError: name 'calculate_entropy' is not defined

# %%
def extract_all_tokens(function_call, list_of_filenames):
    pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    get_completefile=pathname+list_of_filenames+"_funcDef.json"
    #print(function_call)
    if(os.path.isfile(get_completefile)):
        
        with open(get_completefile) as s:
            data1 = json.load(s)
            for search in data1:
                
                #print(get_completefile)
                if search["name"] ==function_call:
                    
                    #print("function_call"+function_call)
                    #print("lol"+function_call)
                    #print("lol2"+function_call)
                    return (search["tokens"])

# %% [markdown]
# # Working

# %%
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")
get_files=[]
c_files=[]
for s in file_list:
    #print(i)
    if s[-10:]=="paths.json":
       c_files.append(s)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)

for file in c_files:
    with open(file) as path_list_file:
        path_list = json.load(path_list_file)
        joint_entropy_list=[]
        knowing_entropy_list=[]
        total=[]
        print(file)
        for path in path_list:
            #print(path)
            
            for node in reversed(path[1:]):
#                 print(node)
# #                 print(path[:path.index(node)])
                
                joint_list = path[:path.index(node)+1]
                knowing_list = path[:path.index(node)]
            
                #print("joint" + str(joint_list))
                #print("knowing" +str(knowing_list))
                tokens_joint=[]
                for iterator in joint_list:
                    search_function=iterator.split(":")
                    #print(iterator)
                    #print(iterator.split(":")[1])
                    #search_function[0][:-2]+search_function[0][-1:]
                    tokens_joint1 = extract_all_tokens(iterator,(search_function[0][:-2]+search_function[0][-1:]))
                    tokens_joint.append(tokens_joint1)
                joint_entropy= calculate_entropy(tokens_joint, False)
                joint_entropy_list.append(joint_entropy)
                #print(joint_list)
                #print(joint_entropy)
                knowing_tokens=[]
                for iterator1 in knowing_list:
                    search_function1=iterator1.split(":")
                    #print(iterator1)
                    #print(iterator.split(":")[1])
                    #search_function[0][:-2]+search_function[0][-1:]
                    knowing_tokens1 = extract_all_tokens(iterator1,(search_function1[0][:-2]+search_function1[0][-1:]))
                    knowing_tokens.append(knowing_tokens1)
                knowing_entropy= calculate_entropy(tokens_joint, False)
                knowing_entropy_list.append(knowing_entropy)
                total.append((joint_entropy_list,knowing_entropy_list))
                #to be deleted later for checking entropy difference:
                for i in range(len(joint_entropy_list)):
                    if joint_entropy_list[i]!=knowing_entropy_list[i]:
                        print(i)
    filename = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"+"tokens.json"
                #print(filename)
    filename1 = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"+str((((file.split("\\"))[8]).split("_"))[0])+".json"
                #print(filename)
    with open(filename, 'w') as fp:
            json.dump(tokens_joint, fp, ensure_ascii=False, indent=4)
    with open(filename1, 'w') as fp:
            json.dump(total, fp, ensure_ascii=False, indent=4)
                #print(knowing_list)
                #print(knowing_entropy)
# knowing_entropy= calculate_entropy(knowing_tokens)
# cond_e = joint_en - knowing_en
# write in file(for file cjpeg.c cond entropy  is x value for joint list)
                    #print(tokens_joint)
#                     print(iterator.split(":")[0])
#                 print("joint" + str(joint_list))
# Out:
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\cjpegc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\djpegc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\jcstestc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\jpegtranc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\md5cmpc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\rdjpgcomc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\tjbenchc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\tjexamplec_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\tjunittestc_callExpr_funcDecl_paths.json
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\wrjpgcomc_callExpr_funcDecl_paths.json

# %%
file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp")
#file_list=get_list_of_files("C:\\Users\\RITIN JAISWAL\\Desktop\\test_case_msc\\lol")
get_files=[]
c_files=[]
for s in file_list:
    #print(i)
    if s[-35:]=="cjpegc_callExpr_funcDecl_paths.json":
       c_files.append(s)
for file in c_files:
    get=(os.path.basename(file).split('_'))
    get_files.append(get)

for file in c_files:
    initial_filename=(os.path.basename(file).split('_'))
    leaf_pathname="C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\"
    leaf_file=leaf_pathname+initial_filename[0]+"_"+initial_filename[1]+"_"+initial_filename[2]+"_nodes.json"
    path1 = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"
    directory = (initial_filename[0])
    path = os.path.join(path1, directory)
    if not os.path.isdir(path):
        os.mkdir(path)
    
    with open(file) as path_list_file:
        path_list = json.load(path_list_file)
        joint_entropy_list=[]
        knowing_entropy_list=[]
        total=[]
        cond_entropy=[]
        print(file)
        final_solution=[]
        for path in path_list:
            #print(path)
            
            for node in reversed(path[1:]):
#                 print(node)
# #                 print(path[:path.index(node)])
                
                joint_list = path[:path.index(node)+1]
                knowing_list = path[:path.index(node)]
            
                #print("joint" + str(joint_list))
                #print("knowing" +str(knowing_list))
                tokens_joint=[]
                for iterator in joint_list:
                    search_function=iterator.split(":")
                    #print(iterator)
                    #print(iterator.split(":")[1])
                    #search_function[0][:-2]+search_function[0][-1:]
                    tokens_joint1 = extract_all_tokens(iterator,(search_function[0][:-2]+search_function[0][-1:]))
                    tokens_joint.append(tokens_joint1)
                joint_entropy= calculate_entropy(tokens_joint, False)
                joint_entropy_list.append(joint_entropy)
                #print(joint_list)
                #print(joint_entropy)
                knowing_tokens=[]
                for iterator1 in knowing_list:
                    search_function1=iterator1.split(":")
                    #print(iterator1)
                    #print(iterator.split(":")[1])
                    #search_function[0][:-2]+search_function[0][-1:]
                    knowing_tokens1 = extract_all_tokens(iterator1,(search_function1[0][:-2]+search_function1[0][-1:]))
                    knowing_tokens.append(knowing_tokens1)
                knowing_entropy= calculate_entropy(knowing_tokens, False)
                knowing_entropy_list.append(knowing_entropy)
                total.append((joint_entropy_list,knowing_entropy_list))
                #to be deleted later for checking entropy difference:
                for i in range(len(joint_entropy_list)):
                    cond_entropy=joint_entropy_list[i]-knowing_entropy_list[i]
                final_solution.append((joint_list,cond_entropy))
                #to be deleted later
    filename = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"+str((((file.split("\\"))[8]).split("_"))[0])+"\\tokens.json"
                #print(filename)
    filename1 = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"+str((((file.split("\\"))[8]).split("_"))[0])+"\\entropy.json"
    filename2 = "C:\\Users\\RITIN JAISWAL\\Desktop\\Finer-Softwares-master (1)\\Finer-Softwares-master\\Libjpeg\\Temp\\Entropy_Calculation\\"+str((((file.split("\\"))[8]).split("_"))[0])+"\\conditional_entropy.json"

    with open(filename, 'w') as fp:
            json.dump(knowing_tokens, fp, ensure_ascii=False, indent=4)
    with open(filename1, 'w') as fp:
            json.dump(total, fp, ensure_ascii=False, indent=4)
    with open(filename2, 'w') as fp:
            json.dump(final_solution, fp, ensure_ascii=False, indent=4)
               
# knowing_entropy= calculate_entropy(knowing_tokens)
# cond_e = joint_en - knowing_en
# write in file(for file cjpeg.c cond entropy  is x value for joint list)
# Out:
# C:\Users\RITIN JAISWAL\Desktop\Finer-Softwares-master (1)\Finer-Softwares-master\Libjpeg\Temp\cjpegc_callExpr_funcDecl_paths.json

# %%
final_solution
# Out:
# [(['cjpeg.c:main', 'djpeg.c:main'], 0.4330891268486772)]

# %%
knowing_entropy_list
# Out:
# [5.8466658460162035,
#  5.816338530737113,
#  6.007527207505092,
#  6.040156582774277,
#  6.007527207505092,
#  5.753879207617132,
#  6.140441914942867,
#  6.08367303765141,
#  6.007527207505092,
#  5.78713709504883,
#  6.102551580458207,
#  6.08367303765141,
#  6.007527207505092,
#  5.739291026630122,
#  5.7665041797270415,
#  6.084124508104212,
#  6.007527207505092,
#  6.08367303765141,
#  6.007527207505092,
#  6.0786502278295655,
#  6.007527207505092,
#  6.102768832316987,
#  6.084124508104212,
#  6.007527207505092,
#  6.113853396294399,
#  6.08367303765141,
#  6.007527207505092,
#  6.107970921609513,
#  6.0786502278295655,
#  6.007527207505092,
#  6.152520758886273,
#  6.08367303765141,
#  6.007527207505092,
#  6.146794666621886,
#  6.0786502278295655,
#  6.007527207505092]

# %%
for i in range(len(joint_entropy_list)):
    if joint_entropy_list[i]!=knowing_entropy_list[i]:
        print(i)

# %%
a="cjpegc_callExpr_funcDecl_paths.json"
print(len(a))
# Out:
# 35
